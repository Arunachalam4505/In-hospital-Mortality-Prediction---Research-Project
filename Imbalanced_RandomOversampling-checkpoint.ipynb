# %%
import pandas as pd
import numpy as np
from sklearn import model_selection, ensemble, metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support as score, precision_score, recall_score, f1_score,accuracy_score
from sklearn.metrics import precision_recall_curve,auc
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from functools import partial
from skopt import space
from skopt import gp_minimize
from numpy import mean
from sklearn.model_selection import cross_val_score
import time
from scipy.stats import uniform
#from bayes_opt import BayesianOptimization
from xgboost import XGBClassifier
from hyperopt import hp, fmin, tpe
import sklearn.tree
from matplotlib import pyplot
from sklearn.preprocessing import scale
from xgboost import XGBClassifier
from sklearn.utils import resample
import numpy

# %%
cd
# Out:
# C:\Users\hdns014

# %%
cd ..
# Out:
# C:\

# %%
cd Program files
# Out:
# C:\Program files

# %%
cd Python39
# Out:
# C:\Program files\Python39

# %%
cd notebooks
# Out:
# C:\Program files\Python39\notebooks

# %%
test = pd.read_csv("validation_p_mortality.csv")
train = pd.read_csv("derivation_p_mortality.csv")

# %%
train=train.drop(train.columns[0],axis=1)
test=test.drop(test.columns[0],axis=1)

# %%
y_train=train[train.columns[0]]
y_test=test[test.columns[0]]
X_train=train.drop(train.columns[0],axis=1)
X_test=test.drop(test.columns[0],axis=1)

# %%
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import StratifiedKFold
from imblearn.under_sampling import NearMiss

# %%
#Logistic Regression Base model
over = RandomOverSampler(sampling_strategy='auto')  
lr_base = sklearn.linear_model.LogisticRegression(max_iter=10000)
pipe = Pipeline([('o', over),('m', lr_base )])
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6361 1157]
#  [  24  106]]
# Precision: 0.083927
# Recall: 0.815385
# F1 score: 0.152190
# Sensitivity :  0.9962411902897416
# Specificity :  0.08392715756136183
# Negative predictive Value:  0.8153846153846154
# Positive Predictive Value:  0.8461026868848098
# Geometric Mean:  0.2891568628730188

# %%
print('Coefficient Values:',pipe['m'].coef_)
print('Intercept Model :',pipe['m'].intercept_)
pd.DataFrame(zip(X_train.columns,np.transpose(pipe['m'].coef_)),columns=['Features','Ceofficients'])
# Out:
# Coefficient Values: [[ 9.69628289e-01 -1.33602934e-01  6.99660969e-02 -1.98640263e-02
#    1.54166349e-01  3.71231367e-01  5.78647970e-02 -3.90573417e-01
#   -6.79114986e-01 -2.58587251e-02  1.03285434e+00 -5.58623486e-01
#   -1.01723362e+00  9.72218409e-06  2.11057850e-02 -1.45537393e-01
#   -3.21381148e-03  1.11180568e-01 -1.19341243e+00 -5.18291022e-01
#    5.48326302e-03 -1.69675011e-02 -1.91563774e-03 -2.82895122e-03
#    1.34433537e-02  5.23768237e-02 -1.97366941e-02  7.37926238e-04
#    9.99962238e-03  2.08763245e-03  2.80386346e-01 -5.03175637e-01
#   -4.75781045e-01 -2.51204147e+00 -2.17690493e-02 -4.90372852e-01
#    5.34165541e-01 -7.04232497e-01  6.52183532e-01]]
# Intercept Model : [-5.1365427]
#                   Features              Ceofficients
# 0            emerg_surgery       [0.969628288668342]
# 1                   female    [-0.13360293437532586]
# 2                      age     [0.06996609694285333]
# 3                    rcri7    [-0.01986402628990683]
# 4                    pimr2      [0.1541663485807753]
# 5                    eci32     [0.37123136713100197]
# 6                     hfrs    [0.057864796973191975]
# 7            obesity_total     [-0.3905734165720821]
# 8             hypertension     [-0.6791149857729882]
# 9                     copd    [-0.02585872511369063]
# 10                 general      [1.0328543376382053]
# 11               neuraxial     [-0.5586234859267037]
# 12              peripheral      [-1.017233618499463]
# 13             crystalloid   [9.722184085524962e-06]
# 14             vasoinoused      [0.0211057849703916]
# 15         vasodilatorused    [-0.14553739265149176]
# 16         surgeryduration  [-0.0032138114765714924]
# 17              lap_actual     [0.11118056793774783]
# 18    mac_adjusted_general     [-1.1934124250065568]
# 19  sbp_maxdelta_rel_innov     [-0.5182910216903857]
# 20            map_total_70    [0.005483263016922138]
# 21    hr_max_pos_abs_innov   [-0.016967501063555393]
# 22    hr_max_neg_abs_innov  [-0.0019156377405395693]
# 23             hr_total_60   [-0.002828951223310946]
# 24            hr_total_100    [0.013443353680329803]
# 25           spo2_total_88    [0.052376823722414326]
# 26            tempabove_38   [-0.019736694070983857]
# 27            tempbelow_36   [0.0007379262376081161]
# 28  etco2_total_30_General    [0.009999622382258943]
# 29  etco2_total_45_General   [0.0020876324503315154]
# 30              proc_neuro      [0.2803863459853367]
# 31               proc_gyne     [-0.5031756373281149]
# 32              proc_ortho     [-0.4757810451100176]
# 33              proc_other     [-2.5120414685985453]
# 34               proc_otol   [-0.021769049259121025]
# 35               proc_plas    [-0.49037285226901595]
# 36               proc_thor      [0.5341655410272844]
# 37                proc_uro     [-0.7042324973158031]
# 38               proc_vasc      [0.6521835315271268]

# %%
r_probs=[0 for _ in range(len(y_test))]
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
lr_auc =roc_auc_score(y_test,lr_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_test, lr_probs, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title('ROC PLOT - LR BASE')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_base_plot1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('PRC PLOT - LR BASE')
#save
plt.savefig('lr_base_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.890120
# AUC:PrecisionRecall=0.168

# %%
from sklearn.calibration import calibration_curve
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]

x,y= calibration_curve(y_test,lr_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_base_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#apparent train
pred1 = model.predict(X_train)

# %%
# print AUC_ROC for apparent train

r_probs=[0 for _ in range(len(y_train))]
lr_probs1=model.predict_proba(X_train)
lr_probs1=lr_probs1[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_train,r_probs)
lr_auc =roc_auc_score(y_train,lr_probs1)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_train, lr_probs1,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_train, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_train, lr_probs1, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title(' APPARENT -ROC PLOT')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_base_apparent1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('APPARENT - PRC PLOT')
#save
plt.savefig('lr_base_apparent2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.889030
# AUC:PrecisionRecall=0.162

# %%
from sklearn.calibration import calibration_curve
lr_probs=model.predict_proba(X_train)
lr_probs=lr_probs[:,1]

x,y= calibration_curve(y_train,lr_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_base_calibration2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving the file
lr_probs=model.predict_proba(X_test)
lr_pos=lr_probs[:,1]
lr_neg=lr_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_LR': pred, 'PredProb_1_LR_base': lr_pos,'PredProb_0_LR_base':lr_neg}).to_csv('lr_base.csv', index=False)

# %%
cm1 = confusion_matrix(y_train, pred1)
print('Apparent - Confusion Matrix:\n',cm1)

precision = precision_score(y_train, pred1)
print('Apparent - Precision: %f' % precision)

recall = recall_score(y_train, pred1)
print('Apparent  - Recall: %f' % recall)

f1 = f1_score(y_train, pred1)
print('Apparent - F1 score: %f' % f1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[1,0])
print('Apparent - Sensitivity : ', sensitivity1 )

specificity1= cm1[1,1]/(cm1[0,1]+cm1[1,1])
print('Apparent  - Specificity : ', specificity1)

NPV = cm1[1,1]/(cm1[1,1]+cm1[1,0])
print('Apparent  - Negative predictive Value: ', NPV)

PPV = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Apparent  - Positive Predictive Value: ', PPV)

import math
gm1=math.sqrt(specificity1*sensitivity1)
print('Apparent  - Geometric Mean: ', gm1)
# Out:
# Apparent - Confusion Matrix:
#  [[17895  4557]
#  [   76   415]]
# Apparent - Precision: 0.083467
# Apparent  - Recall: 0.845214
# Apparent - F1 score: 0.151931
# Apparent - Sensitivity :  0.9957709643314229
# Apparent  - Specificity :  0.083467417538214
# Apparent  - Negative predictive Value:  0.845213849287169
# Apparent  - Positive Predictive Value:  0.7970336718332443
# Apparent  - Geometric Mean:  0.2882957350573901

# %%
#saving file

lr_probs1=model.predict_proba(X_train)
lr_pos1=lr_probs1[:,1]
lr_neg1=lr_probs1[:,0]
pd.DataFrame({'Actual': y_train,'Pred_LR': pred1, 'PredProb_1_LR_base': lr_pos1,'PredProb_0_LR_base':lr_neg1}).to_csv('lr_base_apparent.csv', index=False)

# %%
#Scaling data
scaler=sklearn.preprocessing.StandardScaler().fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import StratifiedKFold

# %%
start = time.time()
space_lr ={
        'max_depth': hp.randint('max_depth', 5, 70),
        'max_features': hp.choice('max_features', ['sqrt', 'log2']),
        'criterion': hp.choice('criterion', ["gini", "entropy"]),
             'min_samples_leaf': hp.choice('min_samples_leaf',[1,100,200,300,400,500]),
'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1)}

def dt(params):
    params = {'max_depth': params['max_depth'],
                  'min_samples_leaf': params['min_samples_leaf'],
                  'criterion': params['criterion'],
                 'max_features': params['max_features'],
             'sampling_strategy':params['sampling_strategy']}


    dt_bo = sklearn.tree.DecisionTreeClassifier(random_state=42,max_depth=params['max_depth'], min_samples_leaf= params['min_samples_leaf'], criterion=params['criterion'],max_features=params['max_features'])
    cv= StratifiedKFold(n_splits=5,random_state=42, shuffle=True)
    over = RandomOverSampler(random_state=42,sampling_strategy=params['sampling_strategy'])
    pipe = Pipeline([('o', over),('m', dt_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1-best_score
    
dt_best_param = fmin(fn=dt,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print('It takes %s minutes' % ((time.time() - start)/60))
print('Decision Tree Best Parameters',dt_best_param)
# Out:
# 100%|███████████████████████████| 24/24 [00:09<00:00,  2.58trial/s, best loss: 0.18518159470827766]
# It takes 0.15490678151448567 minutes
# Decision Tree Best Parameters {'criterion': 1, 'max_depth': 36, 'max_features': 1, 'min_samples_leaf': 3, 'sampling_strategy': 0.4}

# %%
param_values = [x for x in dt_best_param.values()]

if param_values[2] ==0:
    max_features = 'sqrt'
else:
    max_features ='log2'

if param_values[0] == 0:
    criterion = 'entropy'
else:
    criterion= 'gini'
        
over = RandomOverSampler(random_state=42,sampling_strategy=param_values[4])
dt_best =sklearn.tree.DecisionTreeClassifier(random_state=42,
    criterion=criterion,
     max_depth= param_values[1],
    min_samples_leaf= param_values[3],
    max_features=max_features)

pipe = Pipeline([('u', over),('m', dt_best)])                                 
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7285  233]
#  [ 116   14]]
# Precision: 0.056680
# Recall: 0.107692
# F1 score: 0.074271
# Sensitivity :  0.9843264423726523
# Specificity :  0.05668016194331984
# Negative predictive Value:  0.1076923076923077
# Positive Predictive Value:  0.9690077148177707
# Geometric Mean:  0.23620284113188356

# %%
r_probs=[0 for _ in range(len(y_test))]
dt_probs=model.predict_proba(X_test)
dt_probs=dt_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
dt_auc =roc_auc_score(y_test,dt_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(dt_auc))

dt_precision, dt_recall, _ = precision_recall_curve(y_test, dt_probs,pos_label=1)
dt_aucprc=auc(dt_recall, dt_precision)
print('AUC:PrecisionRecall Value =%.3f' % (dt_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
dt_fpr, dt_tpr, thresholds = metrics.roc_curve(y_test, dt_probs, pos_label=1)

    #ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(dt_fpr,dt_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%dt_auc)
plt.title('ROC PLOT - DT ')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('DT_plot1.png', dpi=300, bbox_inches='tight')
plt.show()
    
    #PRC Plot
    
plt.plot(dt_recall, dt_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%dt_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - DT')
plt.legend()
plt.savefig('DT_plot2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.538065
# AUC:PrecisionRecall Value =0.060

# %%
#saving file
dt_probs=model.predict_proba(X_test)
dt_pos=dt_probs[:,1]
dt_neg=dt_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_DT': pred, 'PredProb_1_DT': dt_pos,'PredProb_0_DT':dt_neg}).to_csv('dt.csv', index=False)

# %%
from sklearn.calibration import calibration_curve
dt_probs=model.predict_proba(X_test)
dt_probs=dt_probs[:,1]

x,y= calibration_curve(y_test,dt_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='dt')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('DT_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
pred1 = model.predict(X_train)

# %%
r_probs=[0 for _ in range(len(y_train))]
dt_probs1=model.predict_proba(X_train)
dt_probs1=dt_probs1[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_train,r_probs)
dt_auc =roc_auc_score(y_train,dt_probs1)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(dt_auc))

dt_precision, dt_recall, _ = precision_recall_curve(y_train, dt_probs1,pos_label=1)
dt_aucprc=auc(dt_recall, dt_precision)
print('AUC:PrecisionRecall Value =%.3f' % (dt_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_train, r_probs, pos_label=1)
dt_fpr, dt_tpr, thresholds = metrics.roc_curve(y_train, dt_probs1, pos_label=1)

    #ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(dt_fpr,dt_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%dt_auc)
plt.title('APPARENT - ROC PLOT - DT')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('DT_apparent1.png', dpi=300, bbox_inches='tight')
plt.show()
    
    #PRC Plot
    
plt.plot(dt_recall, dt_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%dt_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('APPARENT - PRC PLOT- DT')
plt.legend()
plt.savefig('DT_apparent2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.998498
# AUC:PrecisionRecall Value =0.942

# %%
#saving file
dt_probs1=model.predict_proba(X_train)
dt_pos1=dt_probs1[:,1]
dt_neg1=dt_probs1[:,0]
pd.DataFrame({'Actual': y_train,'Pred_DT': pred1, 'PredProb_1_DT': dt_pos1,'PredProb_0_DT':dt_neg1}).to_csv('dt_apparent.csv', index=False)

# %%
from sklearn.calibration import calibration_curve
dt_probs1=model.predict_proba(X_train)
dt_probs1=dt_probs1[:,1]
x,y= calibration_curve(y_train,dt_probs1, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='dt')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('DT_calibration2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
cm1 = confusion_matrix(y_train, pred1)
print('Apparent- Confusion Matrix:\n',cm1)

precision = precision_score(y_train, pred1)
print('Apparent - Precision: %f' % precision)

recall = recall_score(y_train, pred1)
print('Apparent  - Recall: %f' % recall)

f1 = f1_score(y_train, pred1)
print('Apparent  - F1 score: %f' % f1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[1,0])
print('Apparent  - Sensitivity : ', sensitivity1 )

specificity1= cm1[1,1]/(cm1[0,1]+cm1[1,1])
print('Apparent  - Specificity : ', specificity1)

NPV = cm1[1,1]/(cm1[1,1]+cm1[1,0])
print('Apparent- Negative predictive Value: ', NPV)

PPV = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Apparent - Positive Predictive Value: ', PPV)

import math
gm1=math.sqrt(specificity1*sensitivity1)
print('Apparent  - Geometric Mean: ', gm1)
# Out:
# Apparent- Confusion Matrix:
#  [[22134   318]
#  [    1   490]]
# Apparent - Precision: 0.606436
# Apparent  - Recall: 0.997963
# Apparent  - F1 score: 0.754426
# Apparent  - Sensitivity :  0.9999548226790151
# Apparent  - Specificity :  0.6064356435643564
# Apparent- Negative predictive Value:  0.9979633401221996
# Apparent - Positive Predictive Value:  0.9858364510956708
# Apparent  - Geometric Mean:  0.7787221882203117

# %%
space_lr = {'max_depth': hp.choice('max_depth', range(5, 70,1)),
                'learning_rate':hp.quniform('learning_rate',0.01,0.5,0.01),
            'n_estimators':hp.choice('n_estimators',range(20,200,5)),
            'gamma':hp.quniform('gamma',0,0.5,0.01),
            'min_child_weight':hp.quniform('min_child_weight',1,10,1),
            #'subsample':hp.quniform('subsample',0.1,1,0.01),
            #'colsample_bytree':hp.quniform('colsample_bytree',0.1,1,0.01),
            'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1)
            
        }


def xgb(params):
    params = {'max_depth': params['max_depth'],
                 'learning_rate': params['learning_rate'],
                  'gamma':params['gamma'],
                  
                'min_child_weight':params['min_child_weight'],
             # 'subsample':params['subsample'],
                  'n_estimators': params['n_estimators'],
            #  'colsample_bytree':params['colsample_bytree'],
             'sampling_strategy' : params['sampling_strategy']     
                 }
    
    xgb_bo = XGBClassifier(random_state=42,max_depth=params['max_depth'],learning_rate=params['learning_rate'], n_estimators = params['n_estimators'], gamma = params['gamma'], min_child_weight = params['min_child_weight'])
    cv= StratifiedKFold(random_state=42, shuffle=True,n_splits=5)
    over = RandomOverSampler(random_state=42,sampling_strategy=params['sampling_strategy'])
    pipe = Pipeline([('o', over),('m', xgb_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1 - best_score
xgb_best_param = fmin(fn=xgb,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print(xgb_best_param)
# Out:
#   0%|                                                       | 0/24 [00:00<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:29:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:29:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:16<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:29:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:33<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:30:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:30:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:52<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:30:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                          | 1/24 [00:59<22:34, 58.89s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:30:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                          | 1/24 [01:06<22:34, 58.89s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:30:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                          | 1/24 [01:13<22:34, 58.89s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:30:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                          | 1/24 [01:21<22:34, 58.89s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:30:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                          | 1/24 [01:28<22:34, 58.89s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:30:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▎                         | 2/24 [01:31<18:44, 51.11s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▎                         | 2/24 [01:38<18:44, 51.11s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▎                         | 2/24 [01:41<18:44, 51.11s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▎                         | 2/24 [01:44<18:44, 51.11s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▎                         | 2/24 [01:46<18:44, 51.11s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▌                        | 3/24 [01:49<14:19, 40.92s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▌                        | 3/24 [01:50<14:19, 40.92s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▌                        | 3/24 [01:52<14:19, 40.92s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▌                        | 3/24 [01:54<14:19, 40.92s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▌                        | 3/24 [01:56<14:19, 40.92s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  17%|████▋                       | 4/24 [01:58<10:28, 31.41s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:31:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  17%|████▋                       | 4/24 [02:02<10:28, 31.41s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  17%|████▋                       | 4/24 [02:03<10:28, 31.41s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  17%|████▋                       | 4/24 [02:05<10:28, 31.41s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|█████▊                      | 5/24 [02:07<07:51, 24.81s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|█████▊                      | 5/24 [02:08<07:51, 24.81s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|█████▊                      | 5/24 [02:10<07:51, 24.81s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|█████▊                      | 5/24 [02:11<07:51, 24.81s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|█████▊                      | 5/24 [02:12<07:51, 24.81s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████                     | 6/24 [02:13<05:43, 19.07s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████                     | 6/24 [02:16<05:43, 19.07s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████                     | 6/24 [02:18<05:43, 19.07s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████                     | 6/24 [02:21<05:43, 19.07s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████                     | 6/24 [02:26<05:43, 19.07s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▏                   | 7/24 [02:31<05:18, 18.75s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:31:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▏                   | 7/24 [02:34<05:18, 18.75s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▏                   | 7/24 [02:41<05:18, 18.75s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▏                   | 7/24 [02:43<05:18, 18.75s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▏                   | 7/24 [02:46<05:18, 18.75s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▎                  | 8/24 [02:48<04:52, 18.31s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▎                  | 8/24 [02:50<04:52, 18.31s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▎                  | 8/24 [02:52<04:52, 18.31s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▎                  | 8/24 [02:54<04:52, 18.31s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:32:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▌                 | 9/24 [02:58<03:57, 15.83s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▌                 | 9/24 [03:01<03:57, 15.83s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▌                 | 9/24 [03:04<03:57, 15.83s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▌                 | 9/24 [03:07<03:57, 15.83s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:32:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▎               | 10/24 [03:15<03:43, 15.98s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▎               | 10/24 [03:16<03:43, 15.98s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:32:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▎               | 10/24 [03:19<03:43, 15.98s/trial, best loss: 0.14012530779618904]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:32:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▎               | 10/24 [03:21<03:43, 15.98s/trial, best loss: 0.14012530779618904]
# ...
#  83%|███████████████████████▎    | 20/24 [06:19<01:08, 17.04s/trial, best loss: 0.1326878019122706]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:35:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  83%|███████████████████████▎    | 20/24 [06:24<01:08, 17.04s/trial, best loss: 0.1326878019122706]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:35:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  83%|███████████████████████▎    | 20/24 [06:28<01:08, 17.04s/trial, best loss: 0.1326878019122706]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:35:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|███████████████████████▋   | 21/24 [06:31<00:53, 17.95s/trial, best loss: 0.13033376968946475]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:35:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|███████████████████████▋   | 21/24 [06:35<00:53, 17.95s/trial, best loss: 0.13033376968946475]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:35:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|███████████████████████▋   | 21/24 [06:38<00:53, 17.95s/trial, best loss: 0.13033376968946475]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|███████████████████████▋   | 21/24 [06:41<00:53, 17.95s/trial, best loss: 0.13033376968946475]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|███████████████████████▋   | 21/24 [06:44<00:53, 17.95s/trial, best loss: 0.13033376968946475]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|█████████████████████████▋  | 22/24 [06:48<00:35, 17.52s/trial, best loss: 0.1283711724327541]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|█████████████████████████▋  | 22/24 [06:51<00:35, 17.52s/trial, best loss: 0.1283711724327541]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|█████████████████████████▋  | 22/24 [06:55<00:35, 17.52s/trial, best loss: 0.1283711724327541]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|█████████████████████████▋  | 22/24 [07:03<00:35, 17.52s/trial, best loss: 0.1283711724327541]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|█████████████████████████▋  | 22/24 [07:06<00:35, 17.52s/trial, best loss: 0.1283711724327541]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|██████████████████████████▊ | 23/24 [07:09<00:18, 18.67s/trial, best loss: 0.1283711724327541]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|██████████████████████████▊ | 23/24 [07:13<00:18, 18.67s/trial, best loss: 0.1283711724327541]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|██████████████████████████▊ | 23/24 [07:17<00:18, 18.67s/trial, best loss: 0.1283711724327541]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|██████████████████████████▊ | 23/24 [07:22<00:18, 18.67s/trial, best loss: 0.1283711724327541]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:36:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|██████████████████████████▊ | 23/24 [07:26<00:18, 18.67s/trial, best loss: 0.1283711724327541]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 100%|████████████████████████████| 24/24 [07:29<00:00, 18.74s/trial, best loss: 0.1283711724327541]
# {'gamma': 0.13, 'learning_rate': 0.1, 'max_depth': 44, 'min_child_weight': 1.0, 'n_estimators': 28, 'sampling_strategy': 0.1}

# %%
param_values = [x for x in xgb_best_param.values()]


xgb_best = XGBClassifier(random_state=42,
   gamma= param_values[0],
    learning_rate= param_values[1],
   max_depth= param_values[2],
   min_child_weight=param_values[3],
n_estimators = param_values[4]
)
over = RandomOverSampler(random_state=42,sampling_strategy=param_values[5])
pipe = Pipeline([('o', over),('m', xgb_best)])
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)
# Out:
# [11:36:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print( 'Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7492   26]
#  [ 128    2]]
# Precision: 0.071429
# Recall: 0.015385
# F1 score: 0.025316
# Sensitivity :  0.9832020997375328
# Specificity :  0.07142857142857142
# Negative predictive Value:  0.015384615384615385
# Positive Predictive Value:  0.9965416334131418
# Geometric Mean:  0.2650070214349495

# %%
r_probs=[0 for _ in range(len(y_test))]
xgb_probs=model.predict_proba(X_test)
xgb_probs=xgb_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
xgb_auc =roc_auc_score(y_test,xgb_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(xgb_auc))

xgb_precision, xgb_recall, _ = precision_recall_curve(y_test, xgb_probs,pos_label=1)
xgb_aucprc=auc(xgb_recall, xgb_precision)
print('AUC:PrecisionRecall Value =%.3f' % (xgb_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
xgb_fpr, xgb_tpr, thresholds = metrics.roc_curve(y_test, xgb_probs, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(xgb_fpr,xgb_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%xgb_auc)
plt.title('ROC PLOT - XGB ')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#plt.savefig('XBB_plot1.png', dpi=300, bbox_inches='tight')
plt.show()

plt.plot(xgb_recall, xgb_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%xgb_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - XGB')
plt.legend()
    #save plot
#plt.savefig('XGB_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.876848
# AUC:PrecisionRecall Value =0.105

# %%
#saving file
xgb_probs=model.predict_proba(X_test)
xgb_pos=xgb_probs[:,1]
xgb_neg=xgb_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_XGB': pred, 'PredProb_1_XGB': xgb_pos,'PredProb_0_XGB':xgb_neg}).to_csv('xgb.csv', index=False)
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
from sklearn.calibration import calibration_curve
xgb_probs=model.predict_proba(X_test)
xgb_probs=xgb_probs[:,1]

x,y= calibration_curve(y_test,xgb_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='xgb')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('XGB_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#Apparent test
pred1 = model.predict(X_train)
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
r_probs=[0 for _ in range(len(y_train))]
xgb_probs1=model.predict_proba(X_train)
xgb_probs1=xgb_probs1[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_train,r_probs)
xgb_auc =roc_auc_score(y_train,xgb_probs1)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(xgb_auc))

xgb_precision, xgb_recall, _ = precision_recall_curve(y_train, xgb_probs1,pos_label=1)
xgb_aucprc=auc(xgb_recall, xgb_precision)
print('AUC:PrecisionRecall Value =%.3f' % (xgb_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_train, r_probs, pos_label=1)
xgb_fpr, xgb_tpr, thresholds = metrics.roc_curve(y_train, xgb_probs1, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(xgb_fpr,xgb_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%xgb_auc)
plt.title('APPARENT - ROC PLOT - XGB')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('XBB_apparent1.png', dpi=300, bbox_inches='tight')
plt.show()

plt.plot(xgb_recall, xgb_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%xgb_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('APPARENT  -PRC PLOT - XGB ')
plt.legend()
    #save plot
plt.savefig('XGBapparent.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.999766
# AUC:PrecisionRecall Value =0.997

# %%
from sklearn.calibration import calibration_curve
xgb_probs1=model.predict_proba(X_train)
xgb_probs1=xgb_probs1[:,1]

x,y= calibration_curve(y_train,xgb_probs1, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='xgb')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('XGB_calibration2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
#saving file
xgb_probs1=model.predict_proba(X_train)
xgb_pos1=xgb_probs1[:,1]
xgb_neg1=xgb_probs1[:,0]
pd.DataFrame({'Actual': y_train,'Pred_XGB': pred1, 'PredProb_1_XGB': xgb_pos1,'PredProb_0_XGB':xgb_neg1}).to_csv('xgb_apparent.csv', index=False)
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
cm1 = confusion_matrix(y_train, pred1)
print('Apparent  - Confusion Matrix:\n',cm1)

precision = precision_score(y_train, pred1)
print('Apparent  - Precision: %f' % precision)

recall = recall_score(y_train, pred1)
print('Apparent - Recall: %f' % recall)

f1 = f1_score(y_train, pred1)
print('Apparent  - F1 score: %f' % f1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[1,0])
print('Apparent  - Sensitivity : ', sensitivity1 )

specificity1= cm1[1,1]/(cm1[0,1]+cm1[1,1])
print('Apparent - Specificity : ', specificity1)

NPV = cm1[1,1]/(cm1[1,1]+cm1[1,0])
print('Apparent  - Negative predictive Value: ', NPV)

PPV = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Apparent  - Positive Predictive Value: ', PPV)

import math
gm1=math.sqrt(specificity1*sensitivity1)
print('Apparent - Geometric Mean: ', gm1)
# Out:
# Apparent  - Confusion Matrix:
#  [[22452     0]
#  [   15   476]]
# Apparent  - Precision: 1.000000
# Apparent - Recall: 0.969450
# Apparent  - F1 score: 0.984488
# Apparent  - Sensitivity :  0.999332354119375
# Apparent - Specificity :  1.0
# Apparent  - Negative predictive Value:  0.9694501018329938
# Apparent  - Positive Predictive Value:  1.0
# Apparent - Geometric Mean:  0.9996661213222018

# %%
#Random Forest Classifier hyper parameter tuning


start = time.time()
space_lr = {'max_depth': hp.randint('max_depth', 6,15),
                'max_features': hp.choice('max_features',['sqrt','log2']),
                'n_estimators': hp.randint('n_estimators', 100,1000),
                'criterion': hp.choice('criterion', ['entropy','gini']),
             'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1),
            'class_weight':hp.choice('class_weight',['balanced_subsample','balanced'])
                    }

def rf(params):
    params = {'max_depth': params['max_depth'],
                  'max_features': params['max_features'],
                  'n_estimators': params['n_estimators'],
                  'criterion': params['criterion'],
              'sampling_strategy': params['sampling_strategy'],
             'class_weight':params['class_weight']
             }
    rf_bo = sklearn.ensemble.RandomForestClassifier(random_state=42,class_weight=params['class_weight'],max_depth=params['max_depth'],max_features= params['max_features'],n_estimators=params['n_estimators'],criterion= params['criterion'])
    cv= StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
    over = RandomOverSampler(sampling_strategy=params['sampling_strategy'], random_state=42)
    pipe = Pipeline([('o', over),('m', rf_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1-best_score

rf_best_param = fmin(fn=rf,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest,
                        )
print('It takes %s minutes' % ((time.time() - start)/60))
print('Random Forest Best Parameters',rf_best_param)
# Out:
# 100%|███████████████████████████| 24/24 [38:18<00:00, 95.75s/trial, best loss: 0.12679713981175955]
# It takes 38.3009114742279 minutes
# Random Forest Best Parameters {'class_weight': 1, 'criterion': 0, 'max_depth': 7, 'max_features': 0, 'n_estimators': 531, 'sampling_strategy': 0.6000000000000001}

# %%
param_values = [x for x in rf_best_param.values()]

if param_values[1] == 1:
    criterion = 'gini'
else:
    criterion= 'entropy'

if param_values[3] == 1:
    max_features = 'log2'
else:
    max_features= 'sqrt'
    
if param_values[0] == 1:
    class_weight = 'balanced'
else:
    class_weight= 'balanced_subsample'

rf_best = sklearn.ensemble.RandomForestClassifier(random_state=42,
criterion= criterion,
max_depth= param_values[2],
max_features= max_features,
n_estimators=param_values[4],
class_weight = class_weight)
over=RandomOverSampler(random_state=42,sampling_strategy=param_values[5])
pipe = Pipeline([('o', over),('m', rf_best)])
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)


cm = confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6568  950]
#  [  32   98]]
# Precision: 0.093511
# Recall: 0.753846
# F1 score: 0.166384
# Sensitivity :  0.9951515151515151
# Specificity :  0.09351145038167939
# Negative predictive Value:  0.7538461538461538
# Positive Predictive Value:  0.8736366054801809
# Geometric Mean:  0.30505419441690024

# %%
r_probs=[0 for _ in range(len(y_test))]
rf_probs=model.predict_proba(X_test)
rf_probs=rf_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
rf_auc =roc_auc_score(y_test,rf_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(rf_auc))

rf_precision, rf_recall, _ = precision_recall_curve(y_test, rf_probs,pos_label=1)
rf_aucprc=auc(rf_recall, rf_precision)
print('AUC:PrecisionRecall Value =%.3f' % (rf_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
rf_fpr, rf_tpr, thresholds = metrics.roc_curve(y_test, rf_probs, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(rf_fpr,rf_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%rf_auc)
plt.title('ROC PLOT - RF')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('RF_plot1.png', dpi=300, bbox_inches='tight')
plt.show()

plt.plot(rf_recall, rf_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%rf_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - RF')
# show the legend
plt.legend()
#save
plt.savefig('RF_plot2.png', dpi=300, bbox_inches='tight')
#show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.904766
# AUC:PrecisionRecall Value =0.137

# %%
from sklearn.calibration import calibration_curve
rf_probs=model.predict_proba(X_test)
rf_probs=rf_probs[:,1]

x,y= calibration_curve(y_test,rf_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='rf')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('RF_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving file
rf_probs=model.predict_proba(X_test)
rf_pos=rf_probs[:,1]
rf_neg=rf_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_RF': pred, 'PredProb_1_RF': rf_pos,'PredProb_0_RF':rf_neg}).to_csv('rf.csv', index=False)

# %%
#Apparent Train
pred1 = model.predict(X_train)

# %%
cm1 = confusion_matrix(y_train, pred1)
print('Apparent  - Confusion Matrix:\n',cm1)

precision = precision_score(y_train, pred1)
print('Apparent - Precision: %f' % precision)

recall = recall_score(y_train, pred1)
print('Apparent  - Recall: %f' % recall)

f1 = f1_score(y_train, pred1)
print('Apparent  - F1 score: %f' % f1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[1,0])
print('Apparent  - Sensitivity : ', sensitivity1 )

specificity1= cm1[1,1]/(cm1[0,1]+cm1[1,1])
print('Apparent  - Specificity : ', specificity1)

NPV = cm1[1,1]/(cm1[1,1]+cm1[1,0])
print('Apparent  - Negative predictive Value: ', NPV)

PPV = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Apparent  - Positive Predictive Value: ', PPV)

import math
gm1=math.sqrt(specificity1*sensitivity1)
print('Apparent - Geometric Mean: ', gm1)
# Out:
# Apparent  - Confusion Matrix:
#  [[18961  3491]
#  [   32   459]]
# Apparent - Precision: 0.116203
# Apparent  - Recall: 0.934827
# Apparent  - F1 score: 0.206710
# Apparent  - Sensitivity :  0.9983151687463803
# Apparent  - Specificity :  0.11620253164556962
# Apparent  - Negative predictive Value:  0.9348268839103869
# Apparent  - Positive Predictive Value:  0.8445127382861215
# Apparent - Geometric Mean:  0.34059763649870417

# %%
r_probs=[0 for _ in range(len(y_train))]
rf_probs1=model.predict_proba(X_train)
rf_probs1=rf_probs1[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_train,r_probs)
rf_auc =roc_auc_score(y_train,rf_probs1)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(rf_auc))

rf_precision, rf_recall, _ = precision_recall_curve(y_train, rf_probs1,pos_label=1)
rf_aucprc=auc(rf_recall, rf_precision)
print('AUC:PrecisionRecall Value =%.3f' % (rf_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_train, r_probs, pos_label=1)
rf_fpr, rf_tpr, thresholds = metrics.roc_curve(y_train, rf_probs1, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(rf_fpr,rf_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%rf_auc)
plt.title('APPARENT -ROC PLOT - RF')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('RF_apparent1.png', dpi=300, bbox_inches='tight')
plt.show()

plt.plot(rf_recall, rf_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%rf_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('APPARENT  - PRC PLOT - RF')
# show the legend
plt.legend()
#save
plt.savefig('RF_apparent2.png', dpi=300, bbox_inches='tight')
#show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.961912
# AUC:PrecisionRecall Value =0.586

# %%
#saving file
rf_probs1=model.predict_proba(X_train)
rf_pos1=rf_probs1[:,1]
rf_neg1=rf_probs1[:,0]
pd.DataFrame({'Actual': y_train,'Pred_RF': pred1, 'PredProb_1_RF': rf_pos1,'PredProb_0_RF':rf_neg1}).to_csv('rf_apparent.csv', index=False)

# %%
from sklearn.calibration import calibration_curve
rf_probs1=model.predict_proba(X_train)
rf_probs1=rf_probs1[:,1]

x,y= calibration_curve(y_train,rf_probs1, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='rf')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('RF_calibration2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#Logistic Regression Hyper Parameter tuning

start = time.time()
space_lr = {'penalty': 'elasticnet',
               'C' : hp.quniform('C',1,1000,10),
                'solver': 'saga',
               #'class_weight' : 'balanced',
               'max_iter': hp.randint('max_iter', 1000,10000) ,
               'l1_ratio':hp.quniform('l1_ratio',0.1,0.9,0.1),
             'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1)
               }
def lr(params):
    params = {'penalty': params['penalty'],
                 'C': params['C'],
                 # 'class_weight': params['class_weight'],                       
                  'solver': params['solver'],
                 'max_iter':params['max_iter'],
              'l1_ratio':params['l1_ratio'],
              'sampling_strategy':params['sampling_strategy']
             }
    lr_bo2 =sklearn.linear_model.LogisticRegression(random_state=42, class_weight='balanced',penalty=params['penalty'], C= params['C'], solver = params['solver'],max_iter = params['max_iter'], l1_ratio= params['l1_ratio'])
    cv= StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
    over = RandomOverSampler(sampling_strategy=0.1, random_state=42)
    pipe = Pipeline([('o', over),('m', lr_bo2)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1 - best_score

lr_best_param = fmin(fn=lr,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print('It takes %s minutes' % ((time.time() - start)/60))
print('Best Paramters for Logistic Regression Elastic Net model',lr_best_param)
# Out:
#  58%|███████████████▊           | 14/24 [05:55<04:13, 25.31s/trial, best loss: 0.12573132897256178]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 100%|███████████████████████████| 24/24 [10:04<00:00, 25.18s/trial, best loss: 0.12571952253438679]
# It takes 10.073643664518992 minutes
# Best Paramters for Logistic Regression Elastic Net model {'C': 10.0, 'l1_ratio': 0.6000000000000001, 'max_iter': 4646, 'sampling_strategy': 0.7000000000000001}

# %%
param_values = [x for x in lr_best_param.values()]

C= param_values[0]
l1_ratio=param_values[1]
max_iter = param_values[2]

        
lr_best= sklearn.linear_model.LogisticRegression(random_state=42,class_weight='balanced',solver='saga',l1_ratio=l1_ratio,penalty='elasticnet',C=C,max_iter=max_iter)
under=RandomOverSampler(random_state=42,sampling_strategy=param_values[3])
pipe = Pipeline([('o', under),('m', lr_best)])
model=pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
#Printing the performance metrics

cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print(' Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print(' F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print(' Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print(' Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6355 1163]
#  [  27  103]]
#  Precision: 0.081359
# Recall: 0.792308
#  F1 score: 0.147564
# Sensitivity :  0.9957693513005328
#  Specificity :  0.08135860979462875
# Negative predictive Value:  0.7923076923076923
#  Positive Predictive Value:  0.8453046022878425
# Geometric Mean:  0.2846303042508135

# %%
r_probs=[0 for _ in range(len(y_test))]
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
lr_auc =roc_auc_score(y_test,lr_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_test, lr_probs, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title('ROC PLOT - LR ELASTIC MODEL')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_elastic_plot1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('PRC PLOT - LR ELASTIC MODEL')
#save
plt.savefig('lr_elastic_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.894661
# AUC:PrecisionRecall=0.169

# %%
from sklearn.calibration import calibration_curve
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]

x,y= calibration_curve(y_test,lr_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_elastic_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving file
lr_probs=model.predict_proba(X_test)
lr_pos=lr_probs[:,1]
lr_neg=lr_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_LR': pred, 'PredProb_1_LR_ELASTIC': lr_pos,'PredProb_0_LR_ELASTIC':lr_neg}).to_csv('lr_elastic.csv', index=False)

# %%
# Printing the coefficient Values

print('Coefficient Values:',pipe['m'].coef_)
print('Intercept Model :',pipe['m'].intercept_)
# Out:
# Coefficient Values: [[ 0.54214494 -0.08889149  0.80864064 -0.01227313  0.33345407  0.43137016
#    0.11870273 -0.17051644 -0.18162488 -0.00746327  0.45399941 -0.13107475
#   -0.15503971  0.01714406 -0.01984116 -0.0283265  -0.28792494  0.08429023
#   -0.57900322 -0.08093509  0.3026049  -0.30126225 -0.03333613 -0.14380788
#    0.33684104  0.15375066 -0.1664963   0.04539845  0.18456883  0.03436056
#    0.1293678  -0.1287783  -0.15117327 -0.44069187  0.06434413 -0.01821828
#    0.16545718 -0.2143894   0.19163453]]
# Intercept Model : [-1.48499101]

# %%
#Apparent Train
pred1 = model.predict(X_train)

# %%
cm1 = confusion_matrix(y_train, pred1)
print('Apparent  - Confusion Matrix:\n',cm1)

precision = precision_score(y_train, pred1)
print('Apparent - Precision: %f' % precision)

recall = recall_score(y_train, pred1)
print('Apparent  - Recall: %f' % recall)

f1 = f1_score(y_train, pred1)
print('Apparent  - F1 score: %f' % f1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[1,0])
print('Apparent  - Sensitivity : ', sensitivity1 )

specificity1= cm1[1,1]/(cm1[0,1]+cm1[1,1])
print('Apparent  - Specificity : ', specificity1)

NPV = cm1[1,1]/(cm1[1,1]+cm1[1,0])
print('Apparent  - Negative predictive Value: ', NPV)

PPV = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Apparent  - Positive Predictive Value: ', PPV)

import math
gm1=math.sqrt(specificity1*sensitivity1)
print('Apparent - Geometric Mean: ', gm1)
# Out:
# Apparent  - Confusion Matrix:
#  [[17937  4515]
#  [   77   414]]
# Apparent - Precision: 0.083993
# Apparent  - Recall: 0.843177
# Apparent  - F1 score: 0.152768
# Apparent  - Sensitivity :  0.9957255467969357
# Apparent  - Specificity :  0.08399269628727937
# Apparent  - Negative predictive Value:  0.8431771894093686
# Apparent  - Positive Predictive Value:  0.7989043292357029
# Apparent - Geometric Mean:  0.2891948710430394

# %%
r_probs=[0 for _ in range(len(y_train))]
lr_probs1=model.predict_proba(X_train)
lr_probs1=lr_probs1[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_train,r_probs)
lr_auc =roc_auc_score(y_train,lr_probs1)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_train, lr_probs1,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_train, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_train, lr_probs1, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title('APPARENT- ROC PLOT')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_elastic_apparent1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('APPARENT - PRC PLOT - LR ELASTIC MODEL')
#save
plt.savefig('lr_elastic_apparent2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.889572
# AUC:PrecisionRecall=0.163

# %%
from sklearn.calibration import calibration_curve

lr_probs1=model.predict_proba(X_train)
lr_probs1=lr_probs1[:,1]
    

x,y= calibration_curve(y_train,lr_probs1, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_elastic_calibration2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving file
lr_probs1=model.predict_proba(X_train)
lr_pos1=lr_probs1[:,1]
lr_neg1=lr_probs1[:,0]
pd.DataFrame({'Actual': y_train,'Pred_LR': pred1, 'PredProb_1_LR_ELASTIC': lr_pos1,'PredProb_0_LR_ELASTIC':lr_neg1}).to_csv('lr_elastic_apparent.csv', index=False)

# %%
import imblearn
from sklearn.ensemble import AdaBoostClassifier

# %%
#Easy ensemble Hyper Parameter tuning

start = time.time()
space_lr = {'n_estimators' :hp.randint('n_estimators', 10,500),
             'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1),
            'base_estimator' :  'AdaBoostClassifier'
            #'base_estimator':hp.choice('base_estimator',AdaBoostClassifier()'])
               }
def lr(params):
    params = {
        'n_estimators': params['n_estimators'],
        'sampling_strategy': params['sampling_strategy'],
        'base_estimator': params['base_estimator']
             }
    lr_bo2 =imblearn.ensemble.EasyEnsembleClassifier(random_state=42, n_estimators =params['n_estimators'], sampling_strategy= params['sampling_strategy'], base_estimator=params['base_estimator'] )
    cv= StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
    best_score = cross_val_score(lr_bo2, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1 - best_score

lr_best_param = fmin(fn=lr,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print('It takes %s minutes' % ((time.time() - start)/60))
print('Best Paramters for Logistic Regression Elastic Net model',lr_best_param)
# Out:
#   8%|███▉                                           | 2/24 [00:00<00:01, 19.05trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#  25%|███████████▊                                   | 6/24 [00:00<00:00, 18.98trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
# ...
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# 100%|██████████████████████████████████████████████| 24/24 [00:01<00:00, 19.42trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object ''AdaBoostClassifier'' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ---------------------------------------------------------------------------
# AllTrialsFailed                           Traceback (most recent call last)
# <ipython-input-75-cf4acdfc4d87> in <module>
#      18     return 1 - best_score
#      19
# ---> 20 lr_best_param = fmin(fn=lr,
#      21                     space=space_lr,
#      22                     max_evals=24,
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     558                 "There are no evaluation tasks, cannot return argmin of task losses."
#     559             )
# --> 560         return trials.argmin
#     561     if len(trials) > 0:
#     562         # Only if there are some successful trail runs, return the best point in
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\hyperopt\base.py in argmin(self)
#     629     @property
#     630     def argmin(self):
# --> 631         best_trial = self.best_trial
#     632         vals = best_trial["misc"]["vals"]
#     633         # unpack the one-element lists to values
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\hyperopt\base.py in best_trial(self)
#     620         ]
#     621         if not candidates:
# --> 622             raise AllTrialsFailed
#     623         losses = [float(t["result"]["loss"]) for t in candidates]
#     624         if len(losses) == 0:
#
# AllTrialsFailed:

# %%
lr_bo2 =imblearn.ensemble.EasyEnsembleClassifier(n_estimators = 100, base_estimator = 'AdaBoostClassifier()')
model=lr_bo2.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
cm = confusion_matrix(y_test, pred)
print('Apparent  - Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Apparent - Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Apparent  - Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('Apparent  - F1 score: %f' % f1)
