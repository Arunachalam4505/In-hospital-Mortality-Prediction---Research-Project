# %%
import pandas as pd
import numpy as np
from sklearn import model_selection, ensemble, metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support as score, precision_score, recall_score, f1_score,accuracy_score
from sklearn.metrics import precision_recall_curve,auc
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from functools import partial
from skopt import space
from skopt import gp_minimize
from numpy import mean
from sklearn.model_selection import cross_val_score
import time
from scipy.stats import uniform
#from bayes_opt import BayesianOptimization
from xgboost import XGBClassifier
from hyperopt import hp, fmin, tpe
import sklearn.tree
from matplotlib import pyplot
from sklearn.preprocessing import scale
from xgboost import XGBClassifier
from sklearn.utils import resample
import numpy

# %%
cd
# Out:
# C:\Users\hdns014

# %%
cd ..
# Out:
# C:\

# %%
cd Program files
# Out:
# C:\Program files

# %%
cd Python39
# Out:
# C:\Program files\Python39

# %%
cd notebooks
# Out:
# C:\Program files\Python39\notebooks

# %%
test = pd.read_csv("validation_p_mortality.csv")
train = pd.read_csv("derivation_p_mortality.csv")

# %%
train=train.drop(train.columns[0],axis=1)
test=test.drop(test.columns[0],axis=1)

# %%
y_train=train[train.columns[0]]
y_test=test[test.columns[0]]
X_train=train.drop(train.columns[0],axis=1)
X_test=test.drop(test.columns[0],axis=1)

# %%
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import StratifiedKFold
from imblearn.under_sampling import NearMiss

# %%
#Logistic Regression Base model
over = RandomOverSampler(sampling_strategy='auto')  
lr_base = sklearn.linear_model.LogisticRegression(max_iter=10000)
pipe = Pipeline([('o', over),('m', lr_base )])
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6346 1172]
#  [  25  105]]
# Precision: 0.082224
# Recall: 0.807692
# F1 score: 0.149254
# Sensitivity :  0.9960759692355988
# Specificity :  0.0822239624119029
# Negative predictive Value:  0.8076923076923077
# Positive Predictive Value:  0.8441074753923916
# Geometric Mean:  0.2861840545065843

# %%
print('Coefficient Values:',pipe['m'].coef_)
print('Intercept Model :',pipe['m'].intercept_)
pd.DataFrame(zip(X_train.columns,np.transpose(pipe['m'].coef_)),columns=['Features','Ceofficients'])
# Out:
# Coefficient Values: [[ 9.72948788e-01 -1.55846409e-01  6.85567451e-02 -2.50816627e-02
#    1.49847944e-01  3.84092695e-01  5.14993800e-02 -4.54185363e-01
#   -5.50343373e-01 -9.13744049e-02  1.21628214e+00 -3.03779648e-01
#   -8.72956141e-01  7.11069365e-06 -3.56580923e-02 -6.94052857e-02
#   -3.21851958e-03  1.39856747e-01 -1.30134173e+00 -5.16020182e-01
#    6.05432498e-03 -1.75890582e-02 -3.05038181e-03 -3.39147320e-03
#    1.32067784e-02  5.01392868e-02 -1.99315123e-02  7.95708876e-04
#    9.41144186e-03  2.87527339e-03  3.88731113e-01 -6.04237399e-01
#   -3.84863914e-01 -2.14669177e+00  1.16192477e-01 -4.07925915e-01
#    5.71717400e-01 -6.51861870e-01  8.40617491e-01]]
# Intercept Model : [-5.12641301]
#                   Features              Ceofficients
# 0            emerg_surgery       [0.972948787529032]
# 1                   female    [-0.15584640877055586]
# 2                      age     [0.06855674505870642]
# 3                    rcri7   [-0.025081662681285193]
# 4                    pimr2      [0.1498479437858232]
# 5                    eci32      [0.3840926953866724]
# 6                     hfrs     [0.05149937996972618]
# 7            obesity_total     [-0.4541853630963707]
# 8             hypertension     [-0.5503433732934333]
# 9                     copd    [-0.09137440488445198]
# 10                 general      [1.2162821354487485]
# 11               neuraxial     [-0.3037796477370708]
# 12              peripheral     [-0.8729561410083047]
# 13             crystalloid   [7.110693645351232e-06]
# 14             vasoinoused   [-0.035658092319693135]
# 15         vasodilatorused    [-0.06940528567354573]
# 16         surgeryduration  [-0.0032185195805881665]
# 17              lap_actual     [0.13985674663012745]
# 18    mac_adjusted_general     [-1.3013417276856423]
# 19  sbp_maxdelta_rel_innov     [-0.5160201821163287]
# 20            map_total_70    [0.006054324982416038]
# 21    hr_max_pos_abs_innov   [-0.017589058168038428]
# 22    hr_max_neg_abs_innov  [-0.0030503818137903914]
# 23             hr_total_60  [-0.0033914731965265757]
# 24            hr_total_100    [0.013206778379218081]
# 25           spo2_total_88     [0.05013928680279348]
# 26            tempabove_38    [-0.01993151230636805]
# 27            tempbelow_36   [0.0007957088756888756]
# 28  etco2_total_30_General    [0.009411441864053984]
# 29  etco2_total_45_General   [0.0028752733851547113]
# 30              proc_neuro      [0.3887311129494748]
# 31               proc_gyne     [-0.6042373989097142]
# 32              proc_ortho    [-0.38486391431987904]
# 33              proc_other      [-2.146691771318515]
# 34               proc_otol     [0.11619247665563563]
# 35               proc_plas    [-0.40792591455284605]
# 36               proc_thor      [0.5717173996816997]
# 37                proc_uro     [-0.6518618698533052]
# 38               proc_vasc      [0.8406174909178818]

# %%
r_probs=[0 for _ in range(len(y_test))]
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
lr_auc =roc_auc_score(y_test,lr_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_test, lr_probs, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title('ROC PLOT - LR BASE')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_base_plot1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('PRC PLOT - LR BASE')
#save
plt.savefig('lr_base_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.892883
# AUC:PrecisionRecall=0.169

# %%
from sklearn.calibration import calibration_curve
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]

x,y= calibration_curve(y_test,lr_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_base_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#apparent train
pred1 = model.predict(X_train)

# %%
# print AUC_ROC for apparent train

r_probs=[0 for _ in range(len(y_train))]
lr_probs1=model.predict_proba(X_train)
lr_probs1=lr_probs1[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_train,r_probs)
lr_auc =roc_auc_score(y_train,lr_probs1)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_train, lr_probs1,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_train, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_train, lr_probs1, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title(' APPARENT -ROC PLOT')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_base_apparent1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('APPARENT - PRC PLOT')
#save
plt.savefig('lr_base_apparent2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.889464
# AUC:PrecisionRecall=0.162

# %%
from sklearn.calibration import calibration_curve
lr_probs=model.predict_proba(X_train)
lr_probs=lr_probs[:,1]

x,y= calibration_curve(y_train,lr_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_base_calibration2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving the file
lr_probs=model.predict_proba(X_test)
lr_pos=lr_probs[:,1]
lr_neg=lr_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_LR': pred, 'PredProb_1_LR_base': lr_pos,'PredProb_0_LR_base':lr_neg}).to_csv('lr_base.csv', index=False)

# %%
cm1 = confusion_matrix(y_train, pred1)
print('Apparent - Confusion Matrix:\n',cm1)

precision = precision_score(y_train, pred1)
print('Apparent - Precision: %f' % precision)

recall = recall_score(y_train, pred1)
print('Apparent  - Recall: %f' % recall)

f1 = f1_score(y_train, pred1)
print('Apparent - F1 score: %f' % f1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[1,0])
print('Apparent - Sensitivity : ', sensitivity1 )

specificity1= cm1[1,1]/(cm1[0,1]+cm1[1,1])
print('Apparent  - Specificity : ', specificity1)

NPV = cm1[1,1]/(cm1[1,1]+cm1[1,0])
print('Apparent  - Negative predictive Value: ', NPV)

PPV = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Apparent  - Positive Predictive Value: ', PPV)

import math
gm1=math.sqrt(specificity1*sensitivity1)
print('Apparent  - Geometric Mean: ', gm1)
# Out:
# Apparent - Confusion Matrix:
#  [[17879  4573]
#  [   77   414]]
# Apparent - Precision: 0.083016
# Apparent  - Recall: 0.843177
# Apparent - F1 score: 0.151150
# Apparent - Sensitivity :  0.9957117398084205
# Apparent  - Specificity :  0.08301584118708642
# Apparent  - Negative predictive Value:  0.8431771894093686
# Apparent  - Positive Predictive Value:  0.7963210404418315
# Apparent  - Geometric Mean:  0.2875062567320116

# %%
#saving file

lr_probs1=model.predict_proba(X_train)
lr_pos1=lr_probs1[:,1]
lr_neg1=lr_probs1[:,0]
pd.DataFrame({'Actual': y_train,'Pred_LR': pred1, 'PredProb_1_LR_base': lr_pos1,'PredProb_0_LR_base':lr_neg1}).to_csv('lr_base_apparent.csv', index=False)

# %%
#Scaling data
scaler=sklearn.preprocessing.StandardScaler().fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import StratifiedKFold

# %%
start = time.time()
space_lr ={
        'max_depth': hp.randint('max_depth', 5, 70),
        'max_features': hp.choice('max_features', ['sqrt', 'log2']),
        'criterion': hp.choice('criterion', ["gini", "entropy"]),
             'min_samples_leaf': hp.choice('min_samples_leaf',[1,100,200,300,400,500]),
'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1)}

def dt(params):
    params = {'max_depth': params['max_depth'],
                  'min_samples_leaf': params['min_samples_leaf'],
                  'criterion': params['criterion'],
                 'max_features': params['max_features'],
             'sampling_strategy':params['sampling_strategy']}


    dt_bo = sklearn.tree.DecisionTreeClassifier(random_state=42,max_depth=params['max_depth'], min_samples_leaf= params['min_samples_leaf'], criterion=params['criterion'],max_features=params['max_features'])
    cv= StratifiedKFold(n_splits=5,random_state=42, shuffle=True)
    over = RandomOverSampler(random_state=42,sampling_strategy=params['sampling_strategy'])
    pipe = Pipeline([('o', over),('m', dt_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='average_precision', cv=cv).mean()
    return 1-best_score
    
dt_best_param = fmin(fn=dt,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print('It takes %s minutes' % ((time.time() - start)/60))
print('Decision Tree Best Parameters',dt_best_param)
# Out:
# 100%|████████████████████████████| 24/24 [00:08<00:00,  2.67trial/s, best loss: 0.8996437830891738]
# It takes 0.14992523590723675 minutes
# Decision Tree Best Parameters {'criterion': 1, 'max_depth': 31, 'max_features': 0, 'min_samples_leaf': 2, 'sampling_strategy': 0.5}

# %%
param_values = [x for x in dt_best_param.values()]

if param_values[2] ==0:
    max_features = 'sqrt'
else:
    max_features ='log2'

if param_values[0] == 0:
    criterion = 'entropy'
else:
    criterion= 'gini'
        
over = RandomOverSampler(random_state=42,sampling_strategy=param_values[4])
dt_best =sklearn.tree.DecisionTreeClassifier(random_state=42,
    criterion=criterion,
     max_depth= param_values[1],
    min_samples_leaf= param_values[3],
    max_features=max_features)

pipe = Pipeline([('u', over),('m', dt_best)])                                 
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7358  160]
#  [ 116   14]]
# Precision: 0.080460
# Recall: 0.107692
# F1 score: 0.092105
# Sensitivity :  0.9844795290339845
# Specificity :  0.08045977011494253
# Negative predictive Value:  0.1076923076923077
# Positive Predictive Value:  0.9787177440808725
# Geometric Mean:  0.28144448224994795

# %%
r_probs=[0 for _ in range(len(y_test))]
dt_probs=model.predict_proba(X_test)
dt_probs=dt_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
dt_auc =roc_auc_score(y_test,dt_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(dt_auc))

dt_precision, dt_recall, _ = precision_recall_curve(y_test, dt_probs,pos_label=1)
dt_aucprc=auc(dt_recall, dt_precision)
print('AUC:PrecisionRecall Value =%.3f' % (dt_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
dt_fpr, dt_tpr, thresholds = metrics.roc_curve(y_test, dt_probs, pos_label=1)

    #ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(dt_fpr,dt_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%dt_auc)
plt.title('ROC PLOT - DT ')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('DT_plot1.png', dpi=300, bbox_inches='tight')
plt.show()
    
    #PRC Plot
    
plt.plot(dt_recall, dt_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%dt_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - DT')
plt.legend()
plt.savefig('DT_plot2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.543202
# AUC:PrecisionRecall Value =0.080

# %%
#saving file
dt_probs=model.predict_proba(X_test)
dt_pos=dt_probs[:,1]
dt_neg=dt_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_DT': pred, 'PredProb_1_DT': dt_pos,'PredProb_0_DT':dt_neg}).to_csv('dt.csv', index=False)

# %%
from sklearn.calibration import calibration_curve
dt_probs=model.predict_proba(X_test)
dt_probs=dt_probs[:,1]

x,y= calibration_curve(y_test,dt_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='dt')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('DT_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
pred1 = model.predict(X_train)

# %%
r_probs=[0 for _ in range(len(y_train))]
dt_probs1=model.predict_proba(X_train)
dt_probs1=dt_probs1[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_train,r_probs)
dt_auc =roc_auc_score(y_train,dt_probs1)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(dt_auc))

dt_precision, dt_recall, _ = precision_recall_curve(y_train, dt_probs1,pos_label=1)
dt_aucprc=auc(dt_recall, dt_precision)
print('AUC:PrecisionRecall Value =%.3f' % (dt_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_train, r_probs, pos_label=1)
dt_fpr, dt_tpr, thresholds = metrics.roc_curve(y_train, dt_probs1, pos_label=1)

    #ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(dt_fpr,dt_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%dt_auc)
plt.title('APPARENT - ROC PLOT - DT')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('DT_apparent1.png', dpi=300, bbox_inches='tight')
plt.show()
    
    #PRC Plot
    
plt.plot(dt_recall, dt_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%dt_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('APPARENT - PRC PLOT- DT')
plt.legend()
plt.savefig('DT_apparent2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.999441
# AUC:PrecisionRecall Value =0.976

# %%
#saving file
dt_probs1=model.predict_proba(X_train)
dt_pos1=dt_probs1[:,1]
dt_neg1=dt_probs1[:,0]
pd.DataFrame({'Actual': y_train,'Pred_DT': pred1, 'PredProb_1_DT': dt_pos1,'PredProb_0_DT':dt_neg1}).to_csv('dt_apparent.csv', index=False)

# %%
from sklearn.calibration import calibration_curve
dt_probs1=model.predict_proba(X_train)
dt_probs1=dt_probs1[:,1]
x,y= calibration_curve(y_train,dt_probs1, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='dt')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('DT_calibration2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
cm1 = confusion_matrix(y_train, pred1)
print('Apparent- Confusion Matrix:\n',cm1)

precision = precision_score(y_train, pred1)
print('Apparent - Precision: %f' % precision)

recall = recall_score(y_train, pred1)
print('Apparent  - Recall: %f' % recall)

f1 = f1_score(y_train, pred1)
print('Apparent  - F1 score: %f' % f1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[1,0])
print('Apparent  - Sensitivity : ', sensitivity1 )

specificity1= cm1[1,1]/(cm1[0,1]+cm1[1,1])
print('Apparent  - Specificity : ', specificity1)

NPV = cm1[1,1]/(cm1[1,1]+cm1[1,0])
print('Apparent- Negative predictive Value: ', NPV)

PPV = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Apparent - Positive Predictive Value: ', PPV)

import math
gm1=math.sqrt(specificity1*sensitivity1)
print('Apparent  - Geometric Mean: ', gm1)
# Out:
# Apparent- Confusion Matrix:
#  [[22312   140]
#  [    0   491]]
# Apparent - Precision: 0.778130
# Apparent  - Recall: 1.000000
# Apparent  - F1 score: 0.875223
# Apparent  - Sensitivity :  1.0
# Apparent  - Specificity :  0.7781299524564184
# Apparent- Negative predictive Value:  1.0
# Apparent - Positive Predictive Value:  0.9937644753251381
# Apparent  - Geometric Mean:  0.8821167453667448

# %%
space_lr = {'max_depth': hp.choice('max_depth', range(5, 70,1)),
                'learning_rate':hp.quniform('learning_rate',0.01,0.5,0.01),
            'n_estimators':hp.choice('n_estimators',range(20,200,5)),
            'gamma':hp.quniform('gamma',0,0.5,0.01),
            'min_child_weight':hp.quniform('min_child_weight',1,10,1),
            #'subsample':hp.quniform('subsample',0.1,1,0.01),
            #'colsample_bytree':hp.quniform('colsample_bytree',0.1,1,0.01),
            'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1)
            
        }


def xgb(params):
    params = {'max_depth': params['max_depth'],
                 'learning_rate': params['learning_rate'],
                  'gamma':params['gamma'],
                  
                'min_child_weight':params['min_child_weight'],
             # 'subsample':params['subsample'],
                  'n_estimators': params['n_estimators'],
            #  'colsample_bytree':params['colsample_bytree'],
             'sampling_strategy' : params['sampling_strategy']     
                 }
    
    xgb_bo = XGBClassifier(random_state=42,max_depth=params['max_depth'],learning_rate=params['learning_rate'], n_estimators = params['n_estimators'], gamma = params['gamma'], min_child_weight = params['min_child_weight'])
    cv= StratifiedKFold(random_state=42, shuffle=True,n_splits=5)
    over = RandomOverSampler(random_state=42,sampling_strategy=params['sampling_strategy'])
    pipe = Pipeline([('o', over),('m', xgb_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='average_precision', cv=cv).mean()
    return 1 - best_score
xgb_best_param = fmin(fn=xgb,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print(xgb_best_param)
# Out:
#   0%|                                                       | 0/24 [00:00<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:29:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:00<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:29:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:10<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:29:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:20<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:29:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:31<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:30:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                           | 1/24 [00:53<20:36, 53.75s/trial, best loss: 0.8675953058773085]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:30:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                           | 1/24 [01:03<20:36, 53.75s/trial, best loss: 0.8675953058773085]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:30:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                           | 1/24 [01:12<20:36, 53.75s/trial, best loss: 0.8675953058773085]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:30:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                           | 1/24 [01:20<20:36, 53.75s/trial, best loss: 0.8675953058773085]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:30:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                           | 1/24 [01:28<20:36, 53.75s/trial, best loss: 0.8675953058773085]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#   8%|██▍                          | 2/24 [01:36<18:32, 50.58s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:30:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▍                          | 2/24 [01:37<18:32, 50.58s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▍                          | 2/24 [01:58<18:32, 50.58s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▍                          | 2/24 [02:00<18:32, 50.58s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▍                          | 2/24 [02:03<18:32, 50.58s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▋                         | 3/24 [02:06<15:28, 44.19s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▋                         | 3/24 [02:08<15:28, 44.19s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▋                         | 3/24 [02:10<15:28, 44.19s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▋                         | 3/24 [02:12<15:28, 44.19s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▋                         | 3/24 [02:14<15:28, 44.19s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  17%|████▊                        | 4/24 [02:16<11:19, 33.99s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  17%|████▊                        | 4/24 [02:18<11:19, 33.99s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  17%|████▊                        | 4/24 [02:21<11:19, 33.99s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  17%|████▊                        | 4/24 [02:23<11:19, 33.99s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  17%|████▊                        | 4/24 [02:26<11:19, 33.99s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|██████                       | 5/24 [02:27<08:36, 27.20s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|██████                       | 5/24 [02:28<08:36, 27.20s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|██████                       | 5/24 [02:30<08:36, 27.20s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|██████                       | 5/24 [02:32<08:36, 27.20s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|██████                       | 5/24 [02:33<08:36, 27.20s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████▎                     | 6/24 [02:34<06:16, 20.91s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████▎                     | 6/24 [02:37<06:16, 20.91s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████▎                     | 6/24 [02:39<06:16, 20.91s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████▎                     | 6/24 [02:42<06:16, 20.91s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████▎                     | 6/24 [02:45<06:16, 20.91s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▍                    | 7/24 [02:47<05:19, 18.77s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▍                    | 7/24 [02:55<05:19, 18.77s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▍                    | 7/24 [02:58<05:19, 18.77s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▍                    | 7/24 [03:00<05:19, 18.77s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▍                    | 7/24 [03:03<05:19, 18.77s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▋                   | 8/24 [03:05<04:55, 18.46s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▋                   | 8/24 [03:07<04:55, 18.46s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▋                   | 8/24 [03:08<04:55, 18.46s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▋                   | 8/24 [03:10<04:55, 18.46s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▋                   | 8/24 [03:12<04:55, 18.46s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▉                  | 9/24 [03:14<03:55, 15.67s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▉                  | 9/24 [03:17<03:55, 15.67s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▉                  | 9/24 [03:20<03:55, 15.67s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▉                  | 9/24 [03:22<03:55, 15.67s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▉                  | 9/24 [03:24<03:55, 15.67s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▋                | 10/24 [03:27<03:26, 14.76s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▋                | 10/24 [03:28<03:26, 14.76s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▋                | 10/24 [03:30<03:26, 14.76s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:32:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▋                | 10/24 [03:31<03:26, 14.76s/trial, best loss: 0.8606093462017341]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ...
#  83%|███████████████████████▎    | 20/24 [06:41<01:14, 18.74s/trial, best loss: 0.8500523156094497]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  83%|███████████████████████▎    | 20/24 [06:44<01:14, 18.74s/trial, best loss: 0.8500523156094497]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  83%|███████████████████████▎    | 20/24 [06:47<01:14, 18.74s/trial, best loss: 0.8500523156094497]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|████████████████████████▌   | 21/24 [06:51<00:53, 17.67s/trial, best loss: 0.8500523156094497]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|████████████████████████▌   | 21/24 [06:54<00:53, 17.67s/trial, best loss: 0.8500523156094497]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|████████████████████████▌   | 21/24 [06:58<00:53, 17.67s/trial, best loss: 0.8500523156094497]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|████████████████████████▌   | 21/24 [07:01<00:53, 17.67s/trial, best loss: 0.8500523156094497]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|████████████████████████▌   | 21/24 [07:05<00:53, 17.67s/trial, best loss: 0.8500523156094497]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#  92%|█████████████████████████▋  | 22/24 [07:08<00:35, 17.64s/trial, best loss: 0.8392188753825545]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:36:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|█████████████████████████▋  | 22/24 [07:14<00:35, 17.64s/trial, best loss: 0.8392188753825545]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|█████████████████████████▋  | 22/24 [07:18<00:35, 17.64s/trial, best loss: 0.8392188753825545]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|█████████████████████████▋  | 22/24 [07:22<00:35, 17.64s/trial, best loss: 0.8392188753825545]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|█████████████████████████▋  | 22/24 [07:26<00:35, 17.64s/trial, best loss: 0.8392188753825545]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|██████████████████████████▊ | 23/24 [07:30<00:18, 18.95s/trial, best loss: 0.8392188753825545]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|██████████████████████████▊ | 23/24 [07:34<00:18, 18.95s/trial, best loss: 0.8392188753825545]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|██████████████████████████▊ | 23/24 [07:37<00:18, 18.95s/trial, best loss: 0.8392188753825545]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:36:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|██████████████████████████▊ | 23/24 [07:41<00:18, 18.95s/trial, best loss: 0.8392188753825545]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:37:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|██████████████████████████▊ | 23/24 [07:44<00:18, 18.95s/trial, best loss: 0.8392188753825545]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 100%|████████████████████████████| 24/24 [07:48<00:00, 19.51s/trial, best loss: 0.8392188753825545]
# {'gamma': 0.24, 'learning_rate': 0.09, 'max_depth': 50, 'min_child_weight': 6.0, 'n_estimators': 35, 'sampling_strategy': 0.1}

# %%
param_values = [x for x in xgb_best_param.values()]


xgb_best = XGBClassifier(random_state=42,
   gamma= param_values[0],
    learning_rate= param_values[1],
   max_depth= param_values[2],
   min_child_weight=param_values[3],
n_estimators = param_values[4]
)
over = RandomOverSampler(random_state=42,sampling_strategy=param_values[5])
pipe = Pipeline([('o', over),('m', xgb_best)])
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)
# Out:
# [16:37:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print( 'Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7490   28]
#  [ 124    6]]
# Precision: 0.176471
# Recall: 0.046154
# F1 score: 0.073171
# Sensitivity :  0.9837142106645653
# Specificity :  0.17647058823529413
# Negative predictive Value:  0.046153846153846156
# Positive Predictive Value:  0.9962756052141527
# Geometric Mean:  0.4166492834643951

# %%
r_probs=[0 for _ in range(len(y_test))]
xgb_probs=model.predict_proba(X_test)
xgb_probs=xgb_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
xgb_auc =roc_auc_score(y_test,xgb_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(xgb_auc))

xgb_precision, xgb_recall, _ = precision_recall_curve(y_test, xgb_probs,pos_label=1)
xgb_aucprc=auc(xgb_recall, xgb_precision)
print('AUC:PrecisionRecall Value =%.3f' % (xgb_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
xgb_fpr, xgb_tpr, thresholds = metrics.roc_curve(y_test, xgb_probs, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(xgb_fpr,xgb_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%xgb_auc)
plt.title('ROC PLOT - XGB ')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#plt.savefig('XBB_plot1.png', dpi=300, bbox_inches='tight')
plt.show()

plt.plot(xgb_recall, xgb_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%xgb_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - XGB')
plt.legend()
    #save plot
#plt.savefig('XGB_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.875387
# AUC:PrecisionRecall Value =0.135

# %%
#saving file
xgb_probs=model.predict_proba(X_test)
xgb_pos=xgb_probs[:,1]
xgb_neg=xgb_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_XGB': pred, 'PredProb_1_XGB': xgb_pos,'PredProb_0_XGB':xgb_neg}).to_csv('xgb.csv', index=False)
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
from sklearn.calibration import calibration_curve
xgb_probs=model.predict_proba(X_test)
xgb_probs=xgb_probs[:,1]

x,y= calibration_curve(y_test,xgb_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='xgb')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('XGB_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#Apparent test
pred1 = model.predict(X_train)
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
r_probs=[0 for _ in range(len(y_train))]
xgb_probs1=model.predict_proba(X_train)
xgb_probs1=xgb_probs1[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_train,r_probs)
xgb_auc =roc_auc_score(y_train,xgb_probs1)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(xgb_auc))

xgb_precision, xgb_recall, _ = precision_recall_curve(y_train, xgb_probs1,pos_label=1)
xgb_aucprc=auc(xgb_recall, xgb_precision)
print('AUC:PrecisionRecall Value =%.3f' % (xgb_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_train, r_probs, pos_label=1)
xgb_fpr, xgb_tpr, thresholds = metrics.roc_curve(y_train, xgb_probs1, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(xgb_fpr,xgb_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%xgb_auc)
plt.title('APPARENT - ROC PLOT - XGB')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('XBB_apparent1.png', dpi=300, bbox_inches='tight')
plt.show()

plt.plot(xgb_recall, xgb_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%xgb_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('APPARENT  -PRC PLOT - XGB ')
plt.legend()
    #save plot
plt.savefig('XGBapparent.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.995565
# AUC:PrecisionRecall Value =0.953

# %%
from sklearn.calibration import calibration_curve
xgb_probs1=model.predict_proba(X_train)
xgb_probs1=xgb_probs1[:,1]

x,y= calibration_curve(y_train,xgb_probs1, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='xgb')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('XGB_calibration2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
#saving file
xgb_probs1=model.predict_proba(X_train)
xgb_pos1=xgb_probs1[:,1]
xgb_neg1=xgb_probs1[:,0]
pd.DataFrame({'Actual': y_train,'Pred_XGB': pred1, 'PredProb_1_XGB': xgb_pos1,'PredProb_0_XGB':xgb_neg1}).to_csv('xgb_apparent.csv', index=False)
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
cm1 = confusion_matrix(y_train, pred1)
print('Apparent  - Confusion Matrix:\n',cm1)

precision = precision_score(y_train, pred1)
print('Apparent  - Precision: %f' % precision)

recall = recall_score(y_train, pred1)
print('Apparent - Recall: %f' % recall)

f1 = f1_score(y_train, pred1)
print('Apparent  - F1 score: %f' % f1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[1,0])
print('Apparent  - Sensitivity : ', sensitivity1 )

specificity1= cm1[1,1]/(cm1[0,1]+cm1[1,1])
print('Apparent - Specificity : ', specificity1)

NPV = cm1[1,1]/(cm1[1,1]+cm1[1,0])
print('Apparent  - Negative predictive Value: ', NPV)

PPV = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Apparent  - Positive Predictive Value: ', PPV)

import math
gm1=math.sqrt(specificity1*sensitivity1)
print('Apparent - Geometric Mean: ', gm1)
# Out:
# Apparent  - Confusion Matrix:
#  [[22446     6]
#  [   79   412]]
# Apparent  - Precision: 0.985646
# Apparent - Recall: 0.839104
# Apparent  - F1 score: 0.906491
# Apparent  - Sensitivity :  0.9964927857935627
# Apparent - Specificity :  0.9856459330143541
# Apparent  - Negative predictive Value:  0.8391038696537678
# Apparent  - Positive Predictive Value:  0.9997327632282202
# Apparent - Geometric Mean:  0.9910545199914932

# %%
#Random Forest Classifier hyper parameter tuning


start = time.time()
space_lr = {'max_depth': hp.randint('max_depth', 6,15),
                'max_features': hp.choice('max_features',['sqrt','log2']),
                'n_estimators': hp.randint('n_estimators', 100,1000),
                'criterion': hp.choice('criterion', ['entropy','gini']),
             'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1),
            'class_weight':hp.choice('class_weight',['balanced_subsample','balanced'])
                    }

def rf(params):
    params = {'max_depth': params['max_depth'],
                  'max_features': params['max_features'],
                  'n_estimators': params['n_estimators'],
                  'criterion': params['criterion'],
              'sampling_strategy': params['sampling_strategy'],
             'class_weight':params['class_weight']
             }
    rf_bo = sklearn.ensemble.RandomForestClassifier(random_state=42,class_weight=params['class_weight'],max_depth=params['max_depth'],max_features= params['max_features'],n_estimators=params['n_estimators'],criterion= params['criterion'])
    cv= StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
    over = RandomOverSampler(sampling_strategy=params['sampling_strategy'], random_state=42)
    pipe = Pipeline([('o', over),('m', rf_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='average_precision', cv=cv).mean()
    return 1-best_score

rf_best_param = fmin(fn=rf,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest,
                        )
print('It takes %s minutes' % ((time.time() - start)/60))
print('Random Forest Best Parameters',rf_best_param)
# Out:
# 100%|████████████████████████████| 24/24 [36:26<00:00, 91.09s/trial, best loss: 0.8567864563705675]
# It takes 36.437370642026266 minutes
# Random Forest Best Parameters {'class_weight': 1, 'criterion': 0, 'max_depth': 6, 'max_features': 0, 'n_estimators': 460, 'sampling_strategy': 0.6000000000000001}

# %%
param_values = [x for x in rf_best_param.values()]

if param_values[1] == 1:
    criterion = 'gini'
else:
    criterion= 'entropy'

if param_values[3] == 1:
    max_features = 'log2'
else:
    max_features= 'sqrt'
    
if param_values[0] == 1:
    class_weight = 'balanced'
else:
    class_weight= 'balanced_subsample'

rf_best = sklearn.ensemble.RandomForestClassifier(random_state=42,
criterion= criterion,
max_depth= param_values[2],
max_features= max_features,
n_estimators=param_values[4],
class_weight = class_weight)
over=RandomOverSampler(random_state=42,sampling_strategy=param_values[5])
pipe = Pipeline([('o', over),('m', rf_best)])
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)


cm = confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6442 1076]
#  [  27  103]]
# Precision: 0.087362
# Recall: 0.792308
# F1 score: 0.157372
# Sensitivity :  0.9958262482609368
# Specificity :  0.08736217133163698
# Negative predictive Value:  0.7923076923076923
# Positive Predictive Value:  0.8568768289438681
# Geometric Mean:  0.29495345957813957

# %%
r_probs=[0 for _ in range(len(y_test))]
rf_probs=model.predict_proba(X_test)
rf_probs=rf_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
rf_auc =roc_auc_score(y_test,rf_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(rf_auc))

rf_precision, rf_recall, _ = precision_recall_curve(y_test, rf_probs,pos_label=1)
rf_aucprc=auc(rf_recall, rf_precision)
print('AUC:PrecisionRecall Value =%.3f' % (rf_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
rf_fpr, rf_tpr, thresholds = metrics.roc_curve(y_test, rf_probs, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(rf_fpr,rf_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%rf_auc)
plt.title('ROC PLOT - RF')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('RF_plot1.png', dpi=300, bbox_inches='tight')
plt.show()

plt.plot(rf_recall, rf_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%rf_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - RF')
# show the legend
plt.legend()
#save
plt.savefig('RF_plot2.png', dpi=300, bbox_inches='tight')
#show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.906633
# AUC:PrecisionRecall Value =0.143

# %%
from sklearn.calibration import calibration_curve
rf_probs=model.predict_proba(X_test)
rf_probs=rf_probs[:,1]

x,y= calibration_curve(y_test,rf_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='rf')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('RF_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving file
rf_probs=model.predict_proba(X_test)
rf_pos=rf_probs[:,1]
rf_neg=rf_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_RF': pred, 'PredProb_1_RF': rf_pos,'PredProb_0_RF':rf_neg}).to_csv('rf.csv', index=False)

# %%
#Apparent Train
pred1 = model.predict(X_train)

# %%
cm1 = confusion_matrix(y_train, pred1)
print('Apparent  - Confusion Matrix:\n',cm1)

precision = precision_score(y_train, pred1)
print('Apparent - Precision: %f' % precision)

recall = recall_score(y_train, pred1)
print('Apparent  - Recall: %f' % recall)

f1 = f1_score(y_train, pred1)
print('Apparent  - F1 score: %f' % f1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[1,0])
print('Apparent  - Sensitivity : ', sensitivity1 )

specificity1= cm1[1,1]/(cm1[0,1]+cm1[1,1])
print('Apparent  - Specificity : ', specificity1)

NPV = cm1[1,1]/(cm1[1,1]+cm1[1,0])
print('Apparent  - Negative predictive Value: ', NPV)

PPV = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Apparent  - Positive Predictive Value: ', PPV)

import math
gm1=math.sqrt(specificity1*sensitivity1)
print('Apparent - Geometric Mean: ', gm1)
# Out:
# Apparent  - Confusion Matrix:
#  [[18351  4101]
#  [   43   448]]
# Apparent - Precision: 0.098483
# Apparent  - Recall: 0.912424
# Apparent  - F1 score: 0.177778
# Apparent  - Sensitivity :  0.9976622811786452
# Apparent  - Specificity :  0.09848318311716861
# Apparent  - Negative predictive Value:  0.9124236252545825
# Apparent  - Positive Predictive Value:  0.8173436664885089
# Apparent - Geometric Mean:  0.31345327742170553

# %%
r_probs=[0 for _ in range(len(y_train))]
rf_probs1=model.predict_proba(X_train)
rf_probs1=rf_probs1[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_train,r_probs)
rf_auc =roc_auc_score(y_train,rf_probs1)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(rf_auc))

rf_precision, rf_recall, _ = precision_recall_curve(y_train, rf_probs1,pos_label=1)
rf_aucprc=auc(rf_recall, rf_precision)
print('AUC:PrecisionRecall Value =%.3f' % (rf_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_train, r_probs, pos_label=1)
rf_fpr, rf_tpr, thresholds = metrics.roc_curve(y_train, rf_probs1, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(rf_fpr,rf_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%rf_auc)
plt.title('APPARENT -ROC PLOT - RF')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('RF_apparent1.png', dpi=300, bbox_inches='tight')
plt.show()

plt.plot(rf_recall, rf_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%rf_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('APPARENT  - PRC PLOT - RF')
# show the legend
plt.legend()
#save
plt.savefig('RF_apparent2.png', dpi=300, bbox_inches='tight')
#show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.939421
# AUC:PrecisionRecall Value =0.420

# %%
#saving file
rf_probs1=model.predict_proba(X_train)
rf_pos1=rf_probs1[:,1]
rf_neg1=rf_probs1[:,0]
pd.DataFrame({'Actual': y_train,'Pred_RF': pred1, 'PredProb_1_RF': rf_pos1,'PredProb_0_RF':rf_neg1}).to_csv('rf_apparent.csv', index=False)

# %%
from sklearn.calibration import calibration_curve
rf_probs1=model.predict_proba(X_train)
rf_probs1=rf_probs1[:,1]

x,y= calibration_curve(y_train,rf_probs1, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='rf')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('RF_calibration2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#Logistic Regression Hyper Parameter tuning

start = time.time()
space_lr = {'penalty': 'elasticnet',
               'C' : hp.quniform('C',1,1000,10),
                'solver': 'saga',
               #'class_weight' : 'balanced',
               'max_iter': hp.randint('max_iter', 1000,10000) ,
               'l1_ratio':hp.quniform('l1_ratio',0.1,0.9,0.1),
             'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1)
               }
def lr(params):
    params = {'penalty': params['penalty'],
                 'C': params['C'],
                 # 'class_weight': params['class_weight'],                       
                  'solver': params['solver'],
                 'max_iter':params['max_iter'],
              'l1_ratio':params['l1_ratio'],
              'sampling_strategy':params['sampling_strategy']
             }
    lr_bo2 =sklearn.linear_model.LogisticRegression(random_state=42, class_weight='balanced',penalty=params['penalty'], C= params['C'], solver = params['solver'],max_iter = params['max_iter'], l1_ratio= params['l1_ratio'])
    cv= StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
    over = RandomOverSampler(sampling_strategy=0.1, random_state=42)
    pipe = Pipeline([('o', over),('m', lr_bo2)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='average_precision', cv=cv).mean()
    return 1 - best_score

lr_best_param = fmin(fn=lr,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print('It takes %s minutes' % ((time.time() - start)/60))
print('Best Paramters for Logistic Regression Elastic Net model',lr_best_param)
# Out:
#  58%|████████████████▎           | 14/24 [05:50<04:09, 24.97s/trial, best loss: 0.8417704174910775]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 100%|████████████████████████████| 24/24 [09:53<00:00, 24.72s/trial, best loss: 0.8417608931830539]
# It takes 9.887983083724976 minutes
# Best Paramters for Logistic Regression Elastic Net model {'C': 10.0, 'l1_ratio': 0.8, 'max_iter': 8616, 'sampling_strategy': 0.2}

# %%
param_values = [x for x in lr_best_param.values()]

C= param_values[0]
l1_ratio=param_values[1]
max_iter = param_values[2]

        
lr_best= sklearn.linear_model.LogisticRegression(random_state=42,class_weight='balanced',solver='saga',l1_ratio=l1_ratio,penalty='elasticnet',C=C,max_iter=max_iter)
under=RandomOverSampler(random_state=42,sampling_strategy=param_values[3])
pipe = Pipeline([('o', under),('m', lr_best)])
model=pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
#Printing the performance metrics

cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print(' Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print(' F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print(' Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print(' Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6373 1145]
#  [  27  103]]
#  Precision: 0.082532
# Recall: 0.792308
#  F1 score: 0.149492
# Sensitivity :  0.99578125
#  Specificity :  0.08253205128205128
# Negative predictive Value:  0.7923076923076923
#  Positive Predictive Value:  0.8476988560787444
# Geometric Mean:  0.28667729102721956

# %%
r_probs=[0 for _ in range(len(y_test))]
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
lr_auc =roc_auc_score(y_test,lr_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_test, lr_probs, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title('ROC PLOT - LR ELASTIC MODEL')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_elastic_plot1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('PRC PLOT - LR ELASTIC MODEL')
#save
plt.savefig('lr_elastic_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.892860
# AUC:PrecisionRecall=0.168

# %%
from sklearn.calibration import calibration_curve
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]

x,y= calibration_curve(y_test,lr_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_elastic_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving file
lr_probs=model.predict_proba(X_test)
lr_pos=lr_probs[:,1]
lr_neg=lr_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_LR': pred, 'PredProb_1_LR_ELASTIC': lr_pos,'PredProb_0_LR_ELASTIC':lr_neg}).to_csv('lr_elastic.csv', index=False)

# %%
# Printing the coefficient Values

print('Coefficient Values:',pipe['m'].coef_)
print('Intercept Model :',pipe['m'].intercept_)
# Out:
# Coefficient Values: [[ 0.503966   -0.06737233  0.82238281 -0.02012436  0.35310818  0.43076443
#    0.15754764 -0.17493047 -0.18551757 -0.01939678  0.46563001 -0.10749792
#   -0.15088712  0.03477307  0.00169398 -0.03253656 -0.29247613  0.09362959
#   -0.60455839 -0.09487092  0.27832328 -0.30828347 -0.00810975 -0.14095219
#    0.33701386  0.15991099 -0.167055    0.06612611  0.18107899  0.01072195
#    0.11945442 -0.13176637 -0.19581883 -0.49515036  0.04343177  0.00253038
#    0.17921321 -0.22272097  0.18496382]]
# Intercept Model : [-1.53038386]

# %%
#Apparent Train
pred1 = model.predict(X_train)

# %%
cm1 = confusion_matrix(y_train, pred1)
print('Apparent  - Confusion Matrix:\n',cm1)

precision = precision_score(y_train, pred1)
print('Apparent - Precision: %f' % precision)

recall = recall_score(y_train, pred1)
print('Apparent  - Recall: %f' % recall)

f1 = f1_score(y_train, pred1)
print('Apparent  - F1 score: %f' % f1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[1,0])
print('Apparent  - Sensitivity : ', sensitivity1 )

specificity1= cm1[1,1]/(cm1[0,1]+cm1[1,1])
print('Apparent  - Specificity : ', specificity1)

NPV = cm1[1,1]/(cm1[1,1]+cm1[1,0])
print('Apparent  - Negative predictive Value: ', NPV)

PPV = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Apparent  - Positive Predictive Value: ', PPV)

import math
gm1=math.sqrt(specificity1*sensitivity1)
print('Apparent - Geometric Mean: ', gm1)
# Out:
# Apparent  - Confusion Matrix:
#  [[17993  4459]
#  [   80   411]]
# Apparent - Precision: 0.084394
# Apparent  - Recall: 0.837067
# Apparent  - F1 score: 0.153330
# Apparent  - Sensitivity :  0.9955735074420407
# Apparent  - Specificity :  0.08439425051334702
# Apparent  - Negative predictive Value:  0.8370672097759674
# Apparent  - Positive Predictive Value:  0.8013985391056476
# Apparent - Geometric Mean:  0.2898632091030442

# %%
r_probs=[0 for _ in range(len(y_train))]
lr_probs1=model.predict_proba(X_train)
lr_probs1=lr_probs1[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_train,r_probs)
lr_auc =roc_auc_score(y_train,lr_probs1)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_train, lr_probs1,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_train, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_train, lr_probs1, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title('APPARENT- ROC PLOT')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_elastic_apparent1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('APPARENT - PRC PLOT - LR ELASTIC MODEL')
#save
plt.savefig('lr_elastic_apparent2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.889475
# AUC:PrecisionRecall=0.163

# %%
from sklearn.calibration import calibration_curve

lr_probs1=model.predict_proba(X_train)
lr_probs1=lr_probs1[:,1]
    

x,y= calibration_curve(y_train,lr_probs1, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_elastic_calibration2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving file
lr_probs1=model.predict_proba(X_train)
lr_pos1=lr_probs1[:,1]
lr_neg1=lr_probs1[:,0]
pd.DataFrame({'Actual': y_train,'Pred_LR': pred1, 'PredProb_1_LR_ELASTIC': lr_pos1,'PredProb_0_LR_ELASTIC':lr_neg1}).to_csv('lr_elastic_apparent.csv', index=False)

# %%
import imblearn
from sklearn.ensemble import AdaBoostClassifier

# %%
#Easy ensemble Hyper Parameter tuning

start = time.time()
space_lr = {'n_estimators' :hp.randint('n_estimators', 10,500),
             'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1),
            'base_estimator' :  ' '
            #'base_estimator':hp.choice('base_estimator',AdaBoostClassifier()'])
               }
def lr(params):
    params = {
        'n_estimators': params['n_estimators'],
        'sampling_strategy': params['sampling_strategy'],
        'base_estimator': params['base_estimator']
             }
    lr_bo2 =imblearn.ensemble.EasyEnsembleClassifier(random_state=42, n_estimators =params['n_estimators'], sampling_strategy= params['sampling_strategy'], base_estimator=params['base_estimator'] )
    cv= StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
    best_score = cross_val_score(lr_bo2, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1 - best_score

lr_best_param = fmin(fn=lr,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print('It takes %s minutes' % ((time.time() - start)/60))
print('Best Paramters for Logistic Regression Elastic Net model',lr_best_param)
# Out:
#   8%|███▉                                           | 2/24 [00:00<00:01, 19.22trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#  29%|█████████████▋                                 | 7/24 [00:00<00:00, 19.80trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
# ...
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# 100%|██████████████████████████████████████████████| 24/24 [00:01<00:00, 19.75trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 223, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=None)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\ensemble\_bagging.py", line 294, in _fit
#     self._validate_estimator()
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\imblearn\ensemble\_easy_ensemble.py", line 187, in _validate_estimator
#     base_estimator = clone(self.base_estimator)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\sklearn\base.py", line 78, in clone
#     raise TypeError("Cannot clone object '%s' (type %s): "
# TypeError: Cannot clone object '' '' (type <class 'str'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ---------------------------------------------------------------------------
# AllTrialsFailed                           Traceback (most recent call last)
# <ipython-input-73-1ce11ded9dbb> in <module>
#      18     return 1 - best_score
#      19
# ---> 20 lr_best_param = fmin(fn=lr,
#      21                     space=space_lr,
#      22                     max_evals=24,
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     558                 "There are no evaluation tasks, cannot return argmin of task losses."
#     559             )
# --> 560         return trials.argmin
#     561     if len(trials) > 0:
#     562         # Only if there are some successful trail runs, return the best point in
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\hyperopt\base.py in argmin(self)
#     629     @property
#     630     def argmin(self):
# --> 631         best_trial = self.best_trial
#     632         vals = best_trial["misc"]["vals"]
#     633         # unpack the one-element lists to values
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\hyperopt\base.py in best_trial(self)
#     620         ]
#     621         if not candidates:
# --> 622             raise AllTrialsFailed
#     623         losses = [float(t["result"]["loss"]) for t in candidates]
#     624         if len(losses) == 0:
#
# AllTrialsFailed:

# %%
lr_bo2 =imblearn.ensemble.EasyEnsembleClassifier(n_estimators = 100, base_estimator = 'AdaBoostClassifier()')
model=lr_bo2.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
cm = confusion_matrix(y_test, pred)
print('Apparent  - Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Apparent - Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Apparent  - Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('Apparent  - F1 score: %f' % f1)
