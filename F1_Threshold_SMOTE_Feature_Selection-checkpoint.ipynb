# %%
import pandas as pd
import numpy as np
from sklearn import model_selection, ensemble, metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support as score, precision_score, recall_score, f1_score,accuracy_score
from sklearn.metrics import precision_recall_curve,auc
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from functools import partial

from numpy import mean
from sklearn.model_selection import cross_val_score
import time
from scipy.stats import uniform
#from bayes_opt import BayesianOptimization
from xgboost import XGBClassifier
from hyperopt import hp, fmin, tpe
import sklearn.tree
from matplotlib import pyplot
from sklearn.preprocessing import scale
from xgboost import XGBClassifier
from sklearn.utils import resample
import numpy

# %%
cd
# Out:
# C:\Users\hdns014

# %%
cd ..
# Out:
# C:\

# %%
cd Program files
# Out:
# C:\Program files

# %%
cd Python39
# Out:
# C:\Program files\Python39

# %%
cd notebooks
# Out:
# C:\Program files\Python39\notebooks

# %%
test = pd.read_csv("validation_p_mortality.csv")
train = pd.read_csv("derivation_p_mortality.csv")

# %%
train=train.drop(train.columns[0],axis=1)
test=test.drop(test.columns[0],axis=1)

# %%
y_train=train[train.columns[0]]
y_test=test[test.columns[0]]
X_train=train.drop(train.columns[0],axis=1)
X_test=test.drop(test.columns[0],axis=1)

# %%
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import StratifiedKFold

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
rf= RandomForestClassifier()
rf.fit(X_train,y_train)
score=np.round(rf.feature_importances_,3)
importances = pd.DataFrame({'feature': X_train.columns,'importance': score})
importances = importances.sort_values('importance', ascending=False).set_index('feature')
plt.rcParams['figure.figsize'] = (11,4)
importances.plot.bar()
# Out:
# <AxesSubplot:xlabel='feature'>

# %%
from sklearn.feature_selection import RFE
import itertools
rf = RandomForestClassifier()
rfe= RFE(rf,n_features_to_select = 30)
rfe=rfe.fit(X_train,y_train)

# %%
X_train= rfe.transform(X_train)
X_test = rfe.transform(X_test)

# %%
#Logistic Regression Base model
over = SMOTE(sampling_strategy='auto')  
lr_base = LogisticRegression(max_iter=10000)
pipe = Pipeline([('o', over),('m', lr_base )])
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6331 1187]
#  [  23  107]]
# Precision: 0.082689
# Recall: 0.823077
# F1 score: 0.150281
# Sensitivity :  0.9963802329241422
# Specificity :  0.08268933539412673
# Negative predictive Value:  0.823076923076923
# Positive Predictive Value:  0.8421122638999734
# Geometric Mean:  0.28703661658461366

# %%
r_probs=[0 for _ in range(len(y_test))]
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
lr_auc =roc_auc_score(y_test,lr_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_test, lr_probs, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title('ROC PLOT - LR BASE')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_base_plot1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('PRC PLOT - LR BASE')
#save
plt.savefig('lr_base_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.908412
# AUC:PrecisionRecall=0.170

# %%
from sklearn.calibration import calibration_curve
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]

x,y= calibration_curve(y_test,lr_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_base_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving the file
lr_probs=model.predict_proba(X_test)
lr_pos=lr_probs[:,1]
lr_neg=lr_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_LR': pred, 'PredProb_1_LR_base': lr_pos,'PredProb_0_LR_base':lr_neg}).to_csv('lr_base.csv', index=False)

# %%
lr_probs = model.predict_proba(X_test)
lr_probs=lr_probs[:,1]
fpr, tpr,thresholds = roc_curve(y_test
#        6.64645903e-01, 6.64525762e-01, 6.64352597e-01, 6.61758677e-01,
#        6.61395186e-01, 6.56447153e-01, 6.55761380e-01, 6.44103316e-01,
#        6.43575508e-01, 6.41558744e-01, 6.41367039e-01, 6.33427816e-01,
#        6.33062763e-01, 6.30476486e-01, 6.30284816e-01, 6.12324933e-01,
#        6.12220655e-01, 6.10009515e-01, 6.09947717e-01, 6.07732148e-01,
#        6.07302604e-01, 5.99550432e-01, 5.99144118e-01, 5.79075441e-01,
#        5.78718234e-01, 5.71448080e-01, 5.71404665e-01, 5.69396744e-01,
#        5.69018102e-01, 5.54246519e-01, 5.54169329e-01, 5.40101902e-01,
#        5.40085483e-01, 5.33165701e-01, 5.32836909e-01, 4.82407100e-01,
#        4.82255617e-01, 4.69325522e-01, 4.69314812e-01, 4.68054594e-01,
#        4.68051507e-01, 4.63261529e-01, 4.63098069e-01, 4.28155119e-01,
#        4.27632127e-01, 4.24836283e-01, 4.24833912e-01, 4.22571811e-01,
#        4.21910175e-01, 4.11557525e-01, 4.11166924e-01, 4.00717610e-01,
#        4.00681619e-01, 3.75769105e-01, 3.75540696e-01, 3.57656128e-01,
#        3.57526768e-01, 3.39165156e-01, 3.38678894e-01, 3.36349226e-01,
#        3.36297280e-01, 3.11832457e-01, 3.11746711e-01, 2.39039713e-01,
#        2.38790261e-01, 2.11874607e-01, 2.11824519e-01, 2.11371891e-01,
#        2.11185759e-01, 2.01092634e-01, 2.00981991e-01, 1.34689833e-01,
#        1.34668753e-01, 1.29724816e-01, 1.29709927e-01, 1.21541341e-01,
#        1.21516784e-01, 7.97463420e-02, 7.97119175e-02, 7.02222179e-02,
#        7.01966393e-02, 8.89169112e-04])

# %%
from sklearn.metrics import f1_score
f1_ls =[]
for thres in thresholds:
    y_pred = np.where(lr_probs> thres, 1,0)
    f1_ls.append(f1_score(y_test,y_pred))
f1_ls = pd.concat([pd.Series(thresholds),pd.Series(f1_ls)], axis=1)
f1_ls.columns= ['thresholds', 'f1']
f1_ls.sort_values(by='f1', ascending = False, inplace=True)
f1_ls
# Out:
#     thresholds        f1
# 51    0.930898  0.249057
# 55    0.923095  0.248227
# 53    0.926182  0.248175
# 52    0.930636  0.248120
# 56    0.923050  0.247350
# ..         ...       ...
# 3     0.995324  0.028986
# 4     0.994710  0.028777
# 2     0.999717  0.015267
# 1     0.999996  0.000000
# 0     1.999996  0.000000
#
# [238 rows x 2 columns]

# %%
pred_best = model.predict_proba(X_test)[:,1]
pred_best[pred_best>0.93] =1
pred_best[pred_best<=0.93] =0

# %%
cm= confusion_matrix(y_test, pred_best)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred_best)
print('Precision: %f' % precision)

recall = recall_score(y_test,pred_best)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred_best)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7413  105]
#  [  96   34]]
# Precision: 0.244604
# Recall: 0.261538
# F1 score: 0.252788
# Sensitivity :  0.9872153415900919
# Specificity :  0.2446043165467626
# Negative predictive Value:  0.26153846153846155
# Positive Predictive Value:  0.9860335195530726
# Geometric Mean:  0.49140322945023795

# %%
import warnings

# %%
test = pd.read_csv("validation_p_mortality.csv")
train = pd.read_csv("derivation_p_mortality.csv")
train=train.drop(train.columns[0],axis=1)
test=test.drop(test.columns[0],axis=1)

y_train=train[train.columns[0]]
y_test=test[test.columns[0]]
X_train=train.drop(train.columns[0],axis=1)
train_x=X_train
X_test=test.drop(test.columns[0],axis=1)

# %%
#Scaling data
import sklearn
scaler=sklearn.preprocessing.StandardScaler().fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.feature_selection import RFE
import itertools
rf = RandomForestClassifier()
rfe= RFE(rf,n_features_to_select = 30)
rfe=rfe.fit(X_train,y_train)

# %%
X_train = rfe.transform(X_train)
X_test = rfe.transform(X_test)

# %%
import time
start = time.time()
space_lr ={
        'max_depth': hp.randint('max_depth', 5, 70),
        'max_features': hp.choice('max_features', ['sqrt', 'log2']),
        'criterion': hp.choice('criterion', ["gini", "entropy"]),
             'min_samples_leaf': hp.choice('min_samples_leaf',[1,100,200,300,400,500]),
 'sampling_strategy':hp.quniform('sampling_strategy',0.1,1,0.1)}


def dt(params):
    params = {'max_depth': params['max_depth'],
                  'min_samples_leaf': params['min_samples_leaf'],
                  'criterion': params['criterion'],
                 'max_features': params['max_features'],
              'sampling_strategy':params['sampling_strategy']
             }
     
    dt_bo = sklearn.tree.DecisionTreeClassifier (random_state=42, max_depth=params['max_depth'], min_samples_leaf= params['min_samples_leaf'], criterion=params['criterion'],max_features=params['max_features'])
    cv= StratifiedKFold(n_splits=5, random_state = 42, shuffle= True)
    over = SMOTE(sampling_strategy= params['sampling_strategy'], random_state=42)
    pipe = Pipeline([('o', over),('m', dt_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1-best_score
    
dt_best_param = fmin(fn=dt,
                   space=space_lr,
                  max_evals=24,
                  rstate=np.random.RandomState(42),
                  algo=tpe.suggest)
print('It takes %s minutes' % ((time.time() - start)/60))
print('Decision Tree Best Parameters',dt_best_param)
# Out:
# 100%|███████████████████████████| 24/24 [00:13<00:00,  1.80trial/s, best loss: 0.19702819266655813]
# It takes 0.22239596843719484 minutes
# Decision Tree Best Parameters {'criterion': 0, 'max_depth': 37, 'max_features': 0, 'min_samples_leaf': 2, 'sampling_strategy': 0.1}

# %%
param_values = [x for x in dt_best_param.values()]

if param_values[2] ==1:
    max_features = 'log2'
else:
    max_features ='sqrt'

if param_values[0] == 1:
    criterion = 'entropy'
else:
    criterion= 'gini'

smote = SMOTE(random_state=42,sampling_strategy= param_values[4])
dt_best =sklearn.tree.DecisionTreeClassifier(random_state=42,
    criterion=criterion,
     max_depth= param_values[1],
    min_samples_leaf= param_values[3],
    max_features=max_features)

pipe = Pipeline([('s', smote),('m', dt_best)])  
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7385  133]
#  [ 119   11]]
# Precision: 0.076389
# Recall: 0.084615
# F1 score: 0.080292
# Sensitivity :  0.9841417910447762
# Specificity :  0.0763888888888889
# Negative predictive Value:  0.08461538461538462
# Positive Predictive Value:  0.9823091247672253
# Geometric Mean:  0.2741851526378325

# %%
r_probs=[0 for _ in range(len(y_test))]
dt_probs=model.predict_proba(X_test)
dt_probs=dt_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
dt_auc =roc_auc_score(y_test,dt_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(dt_auc))

dt_precision, dt_recall, _ = precision_recall_curve(y_test, dt_probs,pos_label=1)
dt_aucprc=auc(dt_recall, dt_precision)
print('AUC:PrecisionRecall Value =%.3f' % (dt_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
dt_fpr, dt_tpr, thresholds = metrics.roc_curve(y_test, dt_probs, pos_label=1)

    #ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(dt_fpr,dt_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%dt_auc)
plt.title('ROC PLOT - DT ')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#plt.savefig('DT_plot1.png', dpi=300, bbox_inches='tight')
plt.show()
    
    #PRC Plot
    
plt.plot(dt_recall, dt_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%dt_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - DT')
plt.legend()
#plt.savefig('DT_plot2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.580254
# AUC:PrecisionRecall Value =0.094

# %%
from sklearn.calibration import calibration_curve
dt_probs=model.predict_proba(X_test)
dt_probs=dt_probs[:,1]

x,y= calibration_curve(y_test,dt_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='dt')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('DT_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving file
dt_probs=model.predict_proba(X_test)
dt_pos=dt_probs[:,1]
dt_neg=dt_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_DT': pred, 'PredProb_1_DT': dt_pos,'PredProb_0_DT':dt_neg}).to_csv('dt.csv', index=False)

# %%
dt_probs = model.predict_proba(X_test)
dt_probs=dt_probs[:,1]
fpr, tpr,thresholds = roc_curve(y_test, dt_probs)
thresholds
# Out:
# array([2.        , 1.        , 0.66666667, 0.5       , 0.33333333,
#        0.25      , 0.14285714, 0.11111111, 0.        ])

# %%
from sklearn.metrics import f1_score
f1_ls =[]
for thres in thresholds:
    y_pred = np.where(dt_probs> thres, 1,0)
    f1_ls.append(f1_score(y_test,y_pred))
f1_ls = pd.concat([pd.Series(thresholds),pd.Series(f1_ls)], axis=1)
f1_ls.columns= ['thresholds', 'f1']
f1_ls.sort_values(by='f1', ascending = False, inplace=True)
f1_ls
# Out:
#    thresholds        f1
# 7    0.111111  0.115299
# 8    0.000000  0.115044
# 6    0.142857  0.111857
# 5    0.250000  0.107623
# 4    0.333333  0.107579
# 2    0.666667  0.086275
# 3    0.500000  0.080292
# 0    2.000000  0.000000
# 1    1.000000  0.000000

# %%
pred_best = model.predict_proba(X_test)[:,1]
pred_best[pred_best>0.11] =1
pred_best[pred_best<=0.11] =0

# %%
cm= confusion_matrix(y_test, pred_best)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred_best)
print('Precision: %f' % precision)

recall = recall_score(y_test,pred_best)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred_best)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7222  296]
#  [ 104   26]]
# Precision: 0.080745
# Recall: 0.200000
# F1 score: 0.115044
# Sensitivity :  0.9858039858039858
# Specificity :  0.08074534161490683
# Negative predictive Value:  0.2
# Positive Predictive Value:  0.9606278265496142
# Geometric Mean:  0.2821330884513186

# %%
space_lr = {'max_depth': hp.choice('max_depth', range(5, 70,1)),
                'learning_rate':hp.quniform('learning_rate',0.01,0.5,0.01),
            'n_estimators':hp.choice('n_estimators',range(20,200,5)),
            'gamma':hp.quniform('gamma',0,0.5,0.01),
            'min_child_weight':hp.quniform('min_child_weight',1,10,1),
            'sampling_strategy':hp.quniform('sampling_strategy',0.1,1,0.1)

            
        }


def xgb(params):
    params = {'max_depth': params['max_depth'],
                 'learning_rate': params['learning_rate'],
                  'gamma':params['gamma'],
                   'min_child_weight':params['min_child_weight'],
                  'n_estimators': params['n_estimators'],
              'sampling_strategy':params['sampling_strategy']
                  }
    
    xgb_bo = XGBClassifier(random_state=42, max_depth= params['max_depth'], learning_rate= params['learning_rate'], gamma=params['gamma'], min_child_weight=params['min_child_weight'],n_estimators=params['n_estimators'])
    cv= StratifiedKFold(n_splits=5, random_state=42,shuffle=True)
    over = SMOTE(sampling_strategy=params['sampling_strategy'], random_state=42)
    pipe = Pipeline([('o', over),('m', xgb_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1 - best_score
xgb_best_param = fmin(fn=xgb,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
warnings.filterwarnings("ignore", category= DeprecationWarning)
print(xgb_best_param)
# Out:
# [08:56:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:00<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:56:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:14<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:56:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:17<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:56:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:20<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:56:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▎                            | 1/24 [00:30<11:48, 30.78s/trial, best loss: 0.139753086906369]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:56:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:57:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▎                            | 1/24 [00:34<11:48, 30.78s/trial, best loss: 0.139753086906369]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:57:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▎                            | 1/24 [00:37<11:48, 30.78s/trial, best loss: 0.139753086906369]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:57:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▎                            | 1/24 [00:40<11:48, 30.78s/trial, best loss: 0.139753086906369]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:57:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▎                            | 1/24 [00:43<11:48, 30.78s/trial, best loss: 0.139753086906369]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:57:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▌                           | 2/24 [00:45<09:32, 26.01s/trial, best loss: 0.139753086906369]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:57:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08

# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [09:09:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|█████████████████████████▉ | 23/24 [13:25<00:30, 30.52s/trial, best loss: 0.13553918059621495]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [09:09:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|█████████████████████████▉ | 23/24 [13:26<00:30, 30.52s/trial, best loss: 0.13553918059621495]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [09:09:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|█████████████████████████▉ | 23/24 [13:28<00:30, 30.52s/trial, best loss: 0.13553918059621495]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [09:09:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|█████████████████████████▉ | 23/24 [13:30<00:30, 30.52s/trial, best loss: 0.13553918059621495]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 100%|████████████████████████████| 24/24 [13:32<00:00, 33.84s/trial, best loss: 0.1346713888463057]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-f3aaebea0f3f> in <module>
#      30                     rstate=np.random.RandomState(42),
#      31                     algo=tpe.suggest)
# ---> 32 warnings.filterwarnings("ignore", category= DeprecationWarning)
#      33 print(xgb_best_param)
#
# NameError: name 'warnings' is not defined

# %%
param_values = [x for x in xgb_best_param.values()]


xgb_best = XGBClassifier(random_state=42,
   gamma= param_values[0],
    learning_rate= param_values[1],
   max_depth= param_values[2],
   min_child_weight=param_values[3],
n_estimators = param_values[4]
)
over = SMOTE(random_state=42,sampling_strategy=param_values[5])
pipe = Pipeline([('o', over),('m', xgb_best)])

model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)
# Out:
# [09:34:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print( 'Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7416  102]
#  [ 111   19]]
# Precision: 0.157025
# Recall: 0.146154
# F1 score: 0.151394
# Sensitivity :  0.9852530888800319
# Specificity :  0.15702479338842976
# Negative predictive Value:  0.14615384615384616
# Positive Predictive Value:  0.9864325618515563
# Geometric Mean:  0.39333085655297784

# %%
r_probs=[0 for _ in range(len(y_test))]
xgb_probs=model.predict_proba(X_test)
xgb_probs=xgb_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
xgb_auc =roc_auc_score(y_test,xgb_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(xgb_auc))

xgb_precision, xgb_recall, _ = precision_recall_curve(y_test, xgb_probs,pos_label=1)
xgb_aucprc=auc(xgb_recall, xgb_precision)
print('AUC:PrecisionRecall Value =%.3f' % (xgb_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
xgb_fpr, xgb_tpr, thresholds = metrics.roc_curve(y_test, xgb_probs, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(xgb_fpr,xgb_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%xgb_auc)
plt.title('ROC PLOT - XGB ')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')


plt.plot(xgb_recall, xgb_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%xgb_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - XGB')
plt.legend()
    #save plot
plt.savefig('XGB_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# Random chance= 0.500000
# AUCROC Value = 0.862538
# AUC:PrecisionRecall Value =0.162

# %%
#saving file
xgb_probs=model.predict_proba(X_test)
xgb_pos=xgb_probs[:,1]
xgb_neg=xgb_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_XGB': pred, 'PredProb_1_XGB': xgb_pos,'PredProb_0_XGB':xgb_neg}).to_csv('xgb.csv', index=False)
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
from sklearn.calibration import calibration_curve
xgb_probs=model.predict_proba(X_test)
xgb_probs=xgb_probs[:,1]

x,y= calibration_curve(y_test,xgb_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='xgb')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('XGB_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
xgb_probs = xgb_best.predict_proba(X_test)
xgb_probs=xgb_probs[:,1]
fpr, tpr,thresholds = roc_curve(y_test, xgb_probs)
thresholds
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# array([1.5083268 , 0.5083267 , 0.44955957, 0.4451706 , 0.42621204,
#        0.38794383, 0.369798  , 0.3656704 , 0.31502426, 0.3128999 ,
#        0.31120616, 0.29672912, 0.26303625, 0.24998674, 0.2485104 ,
#        0.24667309, 0.23262365, 0.20712662, 0.2055116 , 0.20422639,
#        0.19320528, 0.19197841, 0.19045313, 0.16856295, 0.15802908,
#        0.15672122, 0.1556813 , 0.12714079], dtype=float32)

# %%
from sklearn.metrics import f1_score
f1_ls =[]
for thres in thresholds:
    y_pred = np.where(xgb_probs> thres, 1,0)
    f1_ls.append(f1_score(y_test,y_pred))
f1_ls = pd.concat([pd.Series(thresholds),pd.Series(f1_ls)], axis=1)
f1_ls.columns= ['thresholds', 'f1']
f1_ls.sort_values(by='f1', ascending = False, inplace=True)
f1_ls
# Out:
#     thresholds        f1
# 5     0.387944  0.199134
# 6     0.369798  0.197628
# 3     0.445171  0.177778
# 7     0.365670  0.177474
# 4     0.426212  0.175258
# 8     0.315024  0.162857
# 9     0.312900  0.162625
# 12    0.263036  0.157588
# 13    0.249987  0.157434
# 2     0.449560  0.151394
# 10    0.311206  0.142039
# 11    0.296729  0.141553
# 14    0.248510  0.138825
# 15    0.246673  0.134102
# 16    0.232624  0.133609
# 17    0.207127  0.127495
# 18    0.205512  0.117714
# 19    0.204226  0.110260
# 20    0.193205  0.105922
# 21    0.191978  0.098765
# 22    0.190453  0.096137
# 23    0.168563  0.085280
# 24    0.158029  0.078772
# 25    0.156721  0.075064
# 26    0.155681  0.058837
# 27    0.127141  0.049687
# 1     0.508327  0.000000
# 0     1.508327  0.000000

# %%
pred_best = model.predict_proba(X_test)[:,1]
pred_best[pred_best>0.38] =1
pred_best[pred_best<=0.38] =0
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
cm= confusion_matrix(y_test, pred_best)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred_best)
print('Precision: %f' % precision)

recall = recall_score(y_test,pred_best)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred_best)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7192  326]
#  [  80   50]]
# Precision: 0.132979
# Recall: 0.384615
# F1 score: 0.197628
# Sensitivity :  0.988998899889989
# Specificity :  0.13297872340425532
# Negative predictive Value:  0.38461538461538464
# Positive Predictive Value:  0.9566374035647779
# Geometric Mean:  0.3626510873492366

# %%
#Random Forest Classifier hyper parameter tuning


start = time.time()
space_lr = {'max_depth': hp.randint('max_depth', 6,15),
                'max_features': hp.choice('max_features',['sqrt','log2']),
                'n_estimators': hp.randint('n_estimators', 100,1000),
                'criterion': hp.choice('criterion', ['entropy','gini']),
            'sampling_strategy':hp.quniform('sampling_strategy',0.1,1,0.1),
            'class_weight':hp.choice('class_weight',['balanced_subsample','balanced'])
            
                    }

def rf(params):
    params = {'max_depth': params['max_depth'],
                  'max_features': params['max_features'],
                  'n_estimators': params['n_estimators'],
                  'criterion': params['criterion'],
              'sampling_strategy': params['sampling_strategy'],
              'class_weight':params['class_weight']
             }
    rf_bo = sklearn.ensemble.RandomForestClassifier(random_state=42, class_weight=params['class_weight'], max_depth=params['max_depth'], max_features=params['max_features'],
                                                   n_estimators=params['n_estimators'], criterion= params['criterion'])
    cv= StratifiedKFold(n_splits=5, random_state=42, shuffle= True)
    over = SMOTE(sampling_strategy=params['sampling_strategy'],random_state=42)
    pipe = Pipeline([('o', over),('m', rf_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1-best_score

rf_best_param = fmin(fn=rf,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest,
                        )
print('It takes %s minutes' % ((time.time() - start)/60))
print('Random Forest Best Parameters',rf_best_param)
# Out:
# 100%|██████████████████████████| 24/24 [54:31<00:00, 136.32s/trial, best loss: 0.13628770934050927]
# It takes 54.52664025227229 minutes
# Random Forest Best Parameters {'class_weight': 0, 'criterion': 1, 'max_depth': 9, 'max_features': 0, 'n_estimators': 673, 'sampling_strategy': 0.1}

# %%
if param_values[1] == 1:
    criterion = 'gini'
else:
    criterion= 'entropy'

if param_values[3] == 1:
    max_features = 'log2'
else:
    max_features= 'sqrt'
    
if param_values[0] == 1:
    class_weight = 'balanced'
else:
    class_weight= 'balanced_subsample'

rf_best = sklearn.ensemble.RandomForestClassifier(random_state=42,
criterion= criterion,
max_depth= param_values[2],
max_features= max_features,
n_estimators=param_values[4],
class_weight = class_weight)

over = SMOTE(sampling_strategy=param_values[5], random_state=42)
pipe = Pipeline([('o', over),('m', rf_best)])

model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

cm = confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6345 1173]
#  [  32   98]]
# Precision: 0.077105
# Recall: 0.753846
# F1 score: 0.139900
# Sensitivity :  0.9949819664419006
# Specificity :  0.07710464201416208
# Negative predictive Value:  0.7538461538461538
# Positive Predictive Value:  0.843974461292897
# Geometric Mean:  0.27697965328350344

# %%
r_probs=[0 for _ in range(len(y_test))]
rf_probs=model.predict_proba(X_test)
rf_probs=rf_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
rf_auc =roc_auc_score(y_test,rf_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(rf_auc))

rf_precision, rf_recall, _ = precision_recall_curve(y_test, rf_probs,pos_label=1)
rf_aucprc=auc(rf_recall, rf_precision)
print('AUC:PrecisionRecall Value =%.3f' % (rf_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
rf_fpr, rf_tpr, thresholds = metrics.roc_curve(y_test, rf_probs, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(rf_fpr,rf_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%rf_auc)
plt.title('ROC PLOT - RF')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('RF_plot1.png', dpi=300, bbox_inches='tight')
plt.show()

plt.plot(rf_recall, rf_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%rf_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - RF')
# show the legend
plt.legend()
#save
plt.savefig('RF_plot2.png', dpi=300, bbox_inches='tight')
#show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.877445
# AUC:PrecisionRecall Value =0.135

# %%
from sklearn.calibration import calibration_curve
rf_probs=model.predict_proba(X_test)
rf_probs=rf_probs[:,1]

x,y= calibration_curve(y_test,rf_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='rf')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('RF_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving file
rf_probs=model.predict_proba(X_test)
rf_pos=rf_probs[:,1]
rf_neg=rf_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_RF': pred, 'PredProb_1_RF': rf_pos,'PredProb_0_RF':rf_neg}).to_csv('rf.csv', index=False)

# %%
rf_probs=rf_best.predict_proba(X_test)
rf_probs=rf_probs[:,1]
fpr, tpr,thresholds = roc_curve(y_test, rf_probs)
thresholds
# Out:
# array([1.68390562, 0.68390562, 0.67386351, ..., 0.28112891, 0.28101057,
#        0.27096846])

# %%
from sklearn.metrics import f1_score
f1_ls =[]
for thres in thresholds:
    y_pred = np.where(rf_probs> thres, 1,0)
    f1_ls.append(f1_score(y_test,y_pred))
f1_ls = pd.concat([pd.Series(thresholds),pd.Series(f1_ls)], axis=1)
f1_ls.columns= ['thresholds', 'f1']
f1_ls.sort_values(by='f1', ascending = False, inplace=True)
f1_ls
# Out:
#     thresholds        f1
# 87    0.612088  0.235897
# 88    0.611906  0.235294
# 89    0.611455  0.232911
# 78    0.615355  0.232687
# 90    0.611184  0.232323
# ..         ...       ...
# 5     0.659283  0.028571
# 2     0.673864  0.015267
# 3     0.669325  0.014925
# 1     0.683906  0.000000
# 0     1.683906  0.000000
#
# [1113 rows x 2 columns]

# %%
pred_best = model.predict_proba(X_test)[:,1]
pred_best[pred_best>0.612] =1
pred_best[pred_best<=0.612] =0

# %%
cm= confusion_matrix(y_test, pred_best)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred_best)
print('Precision: %f' % precision)

recall = recall_score(y_test,pred_best)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred_best)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7303  215]
#  [  84   46]]
# Precision: 0.176245
# Recall: 0.353846
# F1 score: 0.235294
# Sensitivity :  0.9886286719913361
# Specificity :  0.17624521072796934
# Negative predictive Value:  0.35384615384615387
# Positive Predictive Value:  0.9714019686086726
# Geometric Mean:  0.4174219311761488

# %%
#Logistic Regression Hyper Parameter tuning

start = time.time()
space_lr = {'penalty': 'elasticnet',
               'C' : hp.quniform('C',1,1000,10),
                'solver': 'saga',
               'max_iter': hp.randint('max_iter', 1000,100000) ,
               'l1_ratio':hp.quniform('l1_ratio',0.1,0.9,0.1),
            'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1)
            
               }
def lr(params):
    params = {'penalty': params['penalty'],
                 'C': params['C'],                      
                  'solver': params['solver'],
                 'max_iter':params['max_iter'],
              'l1_ratio':params['l1_ratio'],
              'sampling_strategy':params['sampling_strategy']
             }
    lr_bo2 =sklearn.linear_model.LogisticRegression(random_state=42, class_weight='balanced',penalty=params['penalty'], C= params['C'], solver = params['solver'],max_iter = params['max_iter'], l1_ratio= params['l1_ratio'])
    cv= StratifiedKFold(random_state= 42, shuffle= True, n_splits=5)
    over =SMOTE(sampling_strategy=params['sampling_strategy'], random_state=42)
    pipe = Pipeline([('o', over),('m', lr_bo2)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1 - best_score

lr_best_param = fmin(fn=lr,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print('It takes %s minutes' % ((time.time() - start)/60))
print('Best Paramters for Logistic Regression Elastic Net model',lr_best_param)
# Out:
# 100%|███████████████████████████| 24/24 [01:24<00:00,  3.51s/trial, best loss: 0.12968598193890646]
# It takes 1.4043304721514385 minutes
# Best Paramters for Logistic Regression Elastic Net model {'C': 120.0, 'l1_ratio': 0.9, 'max_iter': 38986, 'sampling_strategy': 0.7000000000000001}

# %%
param_values = [x for x in lr_best_param.values()]

C= param_values[0]
l1_ratio=param_values[1]
max_iter = param_values[2]

lr_best= sklearn.linear_model.LogisticRegression(random_state=42,class_weight='balanced',solver='saga',l1_ratio=l1_ratio,penalty='elasticnet',C=C,max_iter=max_iter)
smote= SMOTE(random_state=42,sampling_strategy=param_values[3])
pipe = Pipeline([('s', smote),('m', lr_best)]) 
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
#Printing the performance metrics

cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print(' Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print(' F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print(' Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print(' Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6317 1201]
#  [  22  108]]
#  Precision: 0.082506
# Recall: 0.830769
#  F1 score: 0.150104
# Sensitivity :  0.9965294210443287
#  Specificity :  0.0825057295645531
# Negative predictive Value:  0.8307692307692308
#  Positive Predictive Value:  0.8402500665070497
# Geometric Mean:  0.28673923156032216

# %%
r_probs=[0 for _ in range(len(y_test))]
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
lr_auc =roc_auc_score(y_test,lr_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_test, lr_probs, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title('ROC PLOT - LR ELASTIC MODEL')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_elastic_plot1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('PRC PLOT - LR ELASTIC MODEL')
#save
plt.savefig('lr_elastic_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.905848
# AUC:PrecisionRecall=0.171

# %%
from sklearn.calibration import calibration_curve
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]

x,y= calibration_curve(y_test,lr_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_elastic_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving file
lr_probs=model.predict_proba(X_test)
lr_pos=lr_probs[:,1]
lr_neg=lr_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_LR': pred, 'PredProb_1_LR_ELASTIC': lr_pos,'PredProb_0_LR_ELASTIC':lr_neg}).to_csv('lr_elastic.csv', index=False)

# %%
# Printing the coefficient Values

print('Coefficient Values:',pipe['m'].coef_)
print('Intercept Model :',pipe['m'].intercept_)
# Out:
# Coefficient Values: [[ 0.57014454 -0.09179324  0.89905964 -0.08786315  0.43698746  0.51241837
#    0.05875344 -0.33349928 -0.24079629  0.00847244  0.76195683  0.05349741
#    0.07072866 -0.33866789  0.11803388 -0.76765024 -0.04368911  0.32864954
#   -0.40118411 -0.13095707 -0.21530397  0.31696917  0.13525385 -0.06137701
#    0.18957142  0.03290902 -0.12940547  0.0944064   0.19935192  0.22608463]]
# Intercept Model : [-1.64454373]

# %%
lr_probs = lr_best.predict_proba(X_test)
lr_probs=lr_probs[:,1]
fpr, tpr,thresholds = roc_curve(y_test, lr_probs)
thresholds
# Out:
# array([1.99999405e+00, 9.99994048e-01, 9.98859389e-01, 9.94395222e-01,
#        9.92620208e-01, 9.89704490e-01, 9.89472072e-01, 9.84774064e-01,
#        9.84545692e-01, 9.84461398e-01, 9.81502673e-01, 9.80494170e-01,
#        9.79490418e-01, 9.78961881e-01, 9.78405432e-01, 9.76836130e-01,
#        9.75795207e-01, 9.70357506e-01, 9.70240699e-01, 9.67599623e-01,
#        9.66900321e-01, 9.65556323e-01, 9.65554245e-01, 9.61719927e-01,
#        9.61674369e-01, 9.61298721e-01, 9.61040822e-01, 9.60618358e-01,
#        9.60286547e-01, 9.58913760e-01, 9.58087430e-01, 9.57395807e-01,
#        9.57393629e-01, 9.55058933e-01, 9.54798422e-01, 9.54748040e-01,
#        5.97804686e-01, 5.92821361e-01, 5.92750949e-01, 5.73819762e-01,
#        5.73333425e-01, 5.68600961e-01, 5.68383907e-01, 5.50256375e-01,
#        5.49748570e-01, 5.38165733e-01, 5.37819174e-01, 5.20160152e-01,
#        5.19486811e-01, 5.11848964e-01, 5.11578676e-01, 4.83752429e-01,
#        4.83742254e-01, 4.80249711e-01, 4.79967952e-01, 4.67618646e-01,
#        4.67614141e-01, 4.44199564e-01, 4.43299779e-01, 4.39620970e-01,
#        4.39473007e-01, 4.34803518e-01, 4.34681934e-01, 4.19116587e-01,
#        4.18838737e-01, 3.97692259e-01, 3.97644105e-01, 3.78204725e-01,
#        3.78101082e-01, 3.63663625e-01, 3.63252129e-01, 3.58883770e-01,
#        3.58302206e-01, 3.26940725e-01, 3.26880192e-01, 3.20342954e-01,
#        3.20077851e-01, 2.35047223e-01, 2.34897660e-01, 1.99868719e-01,
#        1.99850987e-01, 1.95299262e-01, 1.95286441e-01, 1.71329204e-01,
#        1.71312225e-01, 1.53024091e-01, 1.52997562e-01, 1.20875186e-01,
#        1.20874000e-01, 9.04160914e-02, 9.02174244e-02, 5.42765518e-02,
#        5.42670123e-02, 5.13553020e-02, 5.13471045e-02, 7.81029780e-04])

# %%
from sklearn.metrics import f1_score
f1_ls =[]
for thres in thresholds:
    y_pred = np.where(lr_probs> thres, 1,0)
    f1_ls.append(f1_score(y_test,y_pred))
f1_ls = pd.concat([pd.Series(thresholds),pd.Series(f1_ls)], axis=1)
f1_ls.columns= ['thresholds', 'f1']
f1_ls.sort_values(by='f1', ascending = False, inplace=True)
f1_ls
# Out:
#     thresholds        f1
# 59    0.917561  0.263889
# 57    0.919709  0.263345
# 60    0.917407  0.262976
# 58    0.919587  0.262411
# 64    0.906006  0.259494
# ..         ...       ...
# 3     0.994395  0.029630
# 4     0.992620  0.029412
# 2     0.998859  0.015267
# 1     0.999994  0.000000
# 0     1.999994  0.000000
#
# [236 rows x 2 columns]

# %%
pred_best = model.predict_proba(X_test)[:,1]
pred_best[pred_best>0.917] =1
pred_best[pred_best<=0.917] =0

# %%
cm= confusion_matrix(y_test, pred_best)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred_best)
print('Precision: %f' % precision)

recall = recall_score(y_test,pred_best)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred_best)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7397  121]
#  [  91   39]]
# Precision: 0.243750
# Recall: 0.300000
# F1 score: 0.268966
# Sensitivity :  0.9878472222222222
# Specificity :  0.24375
# Negative predictive Value:  0.3
# Positive Predictive Value:  0.9839052939611599
# Geometric Mean:  0.49070129449255245
