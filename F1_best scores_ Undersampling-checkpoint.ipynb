# %%
import pandas as pd
import numpy as np
from sklearn import model_selection, ensemble, metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support as score, precision_score, recall_score, f1_score,accuracy_score
from sklearn.metrics import precision_recall_curve,auc
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from functools import partial

from numpy import mean
from sklearn.model_selection import cross_val_score
import time
from scipy.stats import uniform
#from bayes_opt import BayesianOptimization
from xgboost import XGBClassifier
from hyperopt import hp, fmin, tpe
import sklearn.tree
from matplotlib import pyplot
from sklearn.preprocessing import scale
from xgboost import XGBClassifier
from sklearn.utils import resample
import numpy

# %%
cd
# Out:
# C:\Users\hdns014

# %%
cd ..
# Out:
# C:\

# %%
cd Program files
# Out:
# C:\Program files

# %%
cd Python39
# Out:
# C:\Program files\Python39

# %%
cd notebooks
# Out:
# C:\Program files\Python39\notebooks

# %%
test = pd.read_csv("validation_p_mortality.csv")
train = pd.read_csv("derivation_p_mortality.csv")

# %%
train=train.drop(train.columns[0],axis=1)
test=test.drop(test.columns[0],axis=1)

# %%
y_train=train[train.columns[0]]
y_test=test[test.columns[0]]
X_train=train.drop(train.columns[0],axis=1)
X_test=test.drop(test.columns[0],axis=1)

# %%
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import StratifiedKFold

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
rf= RandomForestClassifier()
rf.fit(X_train,y_train)
score=np.round(rf.feature_importances_,3)
importances = pd.DataFrame({'feature': X_train.columns,'importance': score})
importances = importances.sort_values('importance', ascending=False).set_index('feature')
plt.rcParams['figure.figsize'] = (11,4)
importances.plot.bar()
# Out:
# <AxesSubplot:xlabel='feature'>

# %%
from sklearn.feature_selection import RFE
import itertools
rf = RandomForestClassifier()
rfe= RFE(rf,n_features_to_select = 30)
rfe=rfe.fit(X_train,y_train)

# %%
X_train= rfe.transform(X_train)
X_test = rfe.transform(X_test)

# %%
#Logistic Regression Base model
under = RandomUnderSampler(sampling_strategy='auto')  
lr_base = sklearn.linear_model.LogisticRegression(max_iter=10000)
pipe = Pipeline([('u', under),('m', lr_base )])
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6259 1259]
#  [  22  108]]
# Precision: 0.079005
# Recall: 0.830769
# F1 score: 0.144289
# Sensitivity :  0.9964973730297724
# Specificity :  0.07900512070226774
# Negative predictive Value:  0.8307692307692308
# Positive Predictive Value:  0.8325352487363661
# Geometric Mean:  0.28058580725993587

# %%
print('Coefficient Values:',pipe['m'].coef_)
print('Intercept Model :',pipe['m'].intercept_)
pd.DataFrame(zip(X_train.columns,np.transpose(pipe['m'].coef_)),columns=['Features','Ceofficients'])
# Out:
# Coefficient Values: [[ 8.98450745e-01  9.50186565e-02  6.53352348e-02 -4.30912456e-03
#    2.69413247e-01  2.77728662e-01  8.56955904e-02 -7.74408987e-01
#   -3.06628751e-01  2.67910919e-01  7.93953459e-01  1.68117097e-01
#   -4.39902490e-01  2.06973686e-05 -7.04955116e-02 -9.81580862e-02
#   -3.66791590e-03  4.68304976e-02 -8.60334742e-01 -3.98801479e-01
#    6.36094472e-03 -1.46451570e-02 -2.88384088e-03 -2.96965847e-03
#    1.34838447e-02  2.42888068e-02 -2.37620481e-02  2.34607273e-03
#    8.25595781e-03  1.77288879e-03  5.88604707e-01 -3.62442575e-01
#   -3.27428134e-01 -1.76273419e+00 -1.18524836e-01  1.19725648e-01
#    3.31457449e-01 -6.01255124e-01  6.03758465e-01]]
# Intercept Model : [-4.91154385]
#                   Features              Ceofficients
# 0            emerg_surgery      [0.8984507450529292]
# 1                   female     [0.09501865649786405]
# 2                      age     [0.06533523483116192]
# 3                    rcri7    [-0.00430912456113592]
# 4                    pimr2     [0.26941324710800585]
# 5                    eci32      [0.2777286615559684]
# 6                     hfrs     [0.08569559035720886]
# 7            obesity_total     [-0.7744089872081621]
# 8             hypertension      [-0.306628750514829]
# 9                     copd      [0.2679109194854758]
# 10                 general      [0.7939534590690506]
# 11               neuraxial     [0.16811709745495385]
# 12              peripheral    [-0.43990249019934147]
# 13             crystalloid  [2.0697368581841235e-05]
# 14             vasoinoused    [-0.07049551164569941]
# 15         vasodilatorused     [-0.0981580861595363]
# 16         surgeryduration   [-0.003667915901705103]
# 17              lap_actual     [0.04683049761621268]
# 18    mac_adjusted_general     [-0.8603347416906378]
# 19  sbp_maxdelta_rel_innov     [-0.3988014793936593]
# 20            map_total_70    [0.006360944718519722]
# 21    hr_max_pos_abs_innov    [-0.01464515703050682]
# 22    hr_max_neg_abs_innov  [-0.0028838408828528927]
# 23             hr_total_60   [-0.002969658469754671]
# 24            hr_total_100    [0.013483844656504379]
# 25           spo2_total_88    [0.024288806834699722]
# 26            tempabove_38   [-0.023762048062072282]
# 27            tempbelow_36    [0.002346072733302882]
# 28  etco2_total_30_General    [0.008255957812104676]
# 29  etco2_total_45_General      [0.0017728887867349]
# 30              proc_neuro      [0.5886047067333228]
# 31               proc_gyne    [-0.36244257530267054]
# 32              proc_ortho    [-0.32742813402337895]
# 33              proc_other     [-1.7627341901347433]
# 34               proc_otol    [-0.11852483563070973]
# 35               proc_plas     [0.11972564761683156]
# 36               proc_thor      [0.3314574485104146]
# 37                proc_uro     [-0.6012551238094729]
# 38               proc_vasc      [0.6037584648658839]

# %%
r_probs=[0 for _ in range(len(y_test))]
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
lr_auc =roc_auc_score(y_test,lr_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_test, lr_probs, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title('ROC PLOT - LR BASE')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_base_plot1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('PRC PLOT - LR BASE')
#save
plt.savefig('lr_base_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.901135
# AUC:PrecisionRecall=0.166

# %%
from sklearn.calibration import calibration_curve
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]

x,y= calibration_curve(y_test,lr_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_base_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving the file
lr_probs=model.predict_proba(X_test)
lr_pos=lr_probs[:,1]
lr_neg=lr_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_LR': pred, 'PredProb_1_LR_base': lr_pos,'PredProb_0_LR_base':lr_neg}).to_csv('lr_base.csv', index=False)

# %%
lr_probs = model.predict_proba(X_test)
lr_probs=lr_probs[:,1]
fpr, tpr,thresholds = roc_curve(y_test, lr_probs)
thresholds
# Out:
# array([1.99999986e+00, 9.99999859e-01, 9.99789708e-01, 9.99480429e-01,
#        9.97560098e-01, 9.96952553e-01, 9.88946053e-01, 9.87972543e-01,
#        9.85610122e-01, 9.82853001e-01, 9.75818423e-01, 9.75664144e-01,
#        9.73855764e-01, 9.72090585e-01, 9.71018238e-01, 9.71017569e-01,
#        9.69552805e-01, 9.66122750e-01, 9.65051350e-01, 9.63852361e-01,
#        9.61896667e-01, 9.61193862e-01, 9.59137766e-01, 9.54548702e-01,
#        9.53442638e-01, 9.51204488e-01, 9.45742723e-01, 9.45097119e-01,
#        5.41555040e-01, 5.41329887e-01, 5.38120602e-01, 5.38056779e-01,
#        5.35366413e-01, 5.35310588e-01, 5.15176338e-01, 5.14873077e-01,
#        4.95243282e-01, 4.95082269e-01, 4.86687510e-01, 4.86475407e-01,
#        4.81193667e-01, 4.81161528e-01, 4.51566685e-01, 4.50916259e-01,
#        4.48453122e-01, 4.48111207e-01, 4.38791405e-01, 4.38590173e-01,
#        3.98855468e-01, 3.98751820e-01, 3.97867804e-01, 3.97842263e-01,
#        3.92261040e-01, 3.92133332e-01, 3.72267098e-01, 3.72025711e-01,
#        3.55461663e-01, 3.55268545e-01, 3.37105914e-01, 3.37003164e-01,
#        2.90235249e-01, 2.90224748e-01, 2.81147651e-01, 2.81011100e-01,
#        2.73007556e-01, 2.72919451e-01, 2.19049623e-01, 2.18963804e-01,
#        1.97031951e-01, 1.97020408e-01, 1.75450108e-01, 1.75312216e-01,
#        1.67425949e-01, 1.67201378e-01, 1.03239311e-01, 1.03068439e-01,
#        7.96230765e-02, 7.95890126e-02, 6.33583590e-02, 6.33363195e-02,
#        1.98765588e-03])

# %%
from sklearn.metrics import f1_score
f1_ls =[]
for thres in thresholds:
    y_pred = np.where(lr_probs> thres, 1,0)
    f1_ls.append(f1_score(y_test,y_pred))
f1_ls = pd.concat([pd.Series(thresholds),pd.Series(f1_ls)], axis=1)
f1_ls.columns= ['thresholds', 'f1']
f1_ls.sort_values(by='f1', ascending = False, inplace=True)
f1_ls
# Out:
#     thresholds        f1
# 60    0.867239  0.250000
# 61    0.867138  0.249258
# 62    0.862117  0.248555
# 63    0.861478  0.247839
# 58    0.869234  0.247734
# ..         ...       ...
# 5     0.996953  0.028986
# 2     0.999790  0.015038
# 3     0.999480  0.014925
# 1     1.000000  0.000000
# 0     2.000000  0.000000
#
# [229 rows x 2 columns]

# %%
pred_best = model.predict_proba(X_test)[:,1]
pred_best[pred_best>0.867] =1
pred_best[pred_best<=0.867] =0

# %%
cm= confusion_matrix(y_test, pred_best)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred_best)
print('Precision: %f' % precision)

recall = recall_score(y_test,pred_best)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred_best)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7353  165]
#  [  87   43]]
# Precision: 0.206731
# Recall: 0.330769
# F1 score: 0.254438
# Sensitivity :  0.9883064516129032
# Specificity :  0.20673076923076922
# Negative predictive Value:  0.33076923076923076
# Positive Predictive Value:  0.9780526735833999
# Geometric Mean:  0.45201034609582497

# %%
test = pd.read_csv("validation_p_mortality.csv")
train = pd.read_csv("derivation_p_mortality.csv")
train=train.drop(train.columns[0],axis=1)
test=test.drop(test.columns[0],axis=1)

y_train=train[train.columns[0]]
y_test=test[test.columns[0]]
X_train=train.drop(train.columns[0],axis=1)
train_x=X_train
X_test=test.drop(test.columns[0],axis=1)

# %%
#Scaling data
scaler=sklearn.preprocessing.StandardScaler().fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.feature_selection import RFE
import itertools
rf = RandomForestClassifier()
rfe= RFE(rf,n_features_to_select = 30)
rfe=rfe.fit(X_train,y_train)

# %%
X_train = rfe.transform(X_train)
X_test = rfe.transform(X_test)

# %%
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import StratifiedKFold

# %%
start = time.time()
space_lr ={
        'max_depth': hp.randint('max_depth', 5, 70),
        'max_features': hp.choice('max_features', ['sqrt', 'log2']),
        'criterion': hp.choice('criterion', ["gini", "entropy"]),
             'min_samples_leaf': hp.choice('min_samples_leaf',[1,100,200,300,400,500]),
'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1)}

def dt(params):
    params = {'max_depth': params['max_depth'],
                  'min_samples_leaf': params['min_samples_leaf'],
                  'criterion': params['criterion'],
                 'max_features': params['max_features'],
             'sampling_strategy' : params['sampling_strategy']}


    dt_bo = sklearn.tree.DecisionTreeClassifier (random_state=42,max_depth=params['max_depth'], min_samples_leaf= params['min_samples_leaf'], criterion=params['criterion'],max_features=params['max_features'])
    cv= StratifiedKFold(n_splits=5,random_state=42,shuffle=True)
    over = RandomUnderSampler(random_state=42,sampling_strategy=params['sampling_strategy'])
    pipe = Pipeline([('o', over),('m', dt_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1-best_score
    
dt_best_param = fmin(fn=dt,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print('It takes %s minutes' % ((time.time() - start)/60))
print('Decision Tree Best Parameters',dt_best_param)
# Out:
# 100%|████████████████████████████| 24/24 [00:02<00:00, 11.37trial/s, best loss: 0.2092573666173777]
# It takes 0.035318668683369955 minutes
# Decision Tree Best Parameters {'criterion': 0, 'max_depth': 43, 'max_features': 0, 'min_samples_leaf': 1, 'sampling_strategy': 0.1}

# %%
param_values = [x for x in dt_best_param.values()]

if param_values[2] ==1:
    max_features = 'log2'
else:
    max_features ='sqrt'

if param_values[0] == 1:
    criterion = 'entropy'
else:
    criterion= 'gini'
        


under = RandomUnderSampler(random_state=42,sampling_strategy=param_values[4])
dt_best =sklearn.tree.DecisionTreeClassifier(random_state=42,
    criterion=criterion,
     max_depth= param_values[1],
    min_samples_leaf= param_values[3],
    max_features=max_features)

                                   
pipe = Pipeline([('u', under),('m', dt_best)])  
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7048  470]
#  [  93   37]]
# Precision: 0.072978
# Recall: 0.284615
# F1 score: 0.116170
# Sensitivity :  0.9869766139196191
# Specificity :  0.07297830374753451
# Negative predictive Value:  0.2846153846153846
# Positive Predictive Value:  0.9374833732375631
# Geometric Mean:  0.2683801019493417

# %%
r_probs=[0 for _ in range(len(y_test))]
dt_probs=model.predict_proba(X_test)
dt_probs=dt_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
dt_auc =roc_auc_score(y_test,dt_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(dt_auc))

dt_precision, dt_recall, _ = precision_recall_curve(y_test, dt_probs,pos_label=1)
dt_aucprc=auc(dt_recall, dt_precision)
print('AUC:PrecisionRecall Value =%.3f' % (dt_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
dt_fpr, dt_tpr, thresholds = metrics.roc_curve(y_test, dt_probs, pos_label=1)

    #ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(dt_fpr,dt_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%dt_auc)
plt.title('ROC PLOT - DT ')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('DT_plot1.png', dpi=300, bbox_inches='tight')
plt.show()
    
    #PRC Plot
    
plt.plot(dt_recall, dt_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%dt_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - DT')
plt.legend()
plt.savefig('DT_plot2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.611049
# AUC:PrecisionRecall Value =0.185

# %%
from sklearn.calibration import calibration_curve
dt_probs=model.predict_proba(X_test)
dt_probs=dt_probs[:,1]

x,y= calibration_curve(y_test,dt_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='dt')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('DT_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#saving file
dt_probs=model.predict_proba(X_test)
dt_pos=dt_probs[:,1]
dt_neg=dt_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_DT': pred, 'PredProb_1_DT': dt_pos,'PredProb_0_DT':dt_neg}).to_csv('dt.csv', index=False)

# %%
dt_probs = model.predict_proba(X_test)
dt_probs=dt_probs[:,1]
fpr, tpr,thresholds = roc_curve(y_test, dt_probs)
thresholds
# Out:
# array([2., 1., 0.])

# %%
from sklearn.metrics import f1_score
f1_ls =[]
for thres in thresholds:
    y_pred = np.where(dt_probs> thres, 1,0)
    f1_ls.append(f1_score(y_test,y_pred))
f1_ls = pd.concat([pd.Series(thresholds),pd.Series(f1_ls)], axis=1)
f1_ls.columns= ['thresholds', 'f1']
f1_ls.sort_values(by='f1', ascending = False, inplace=True)
f1_ls
# Out:
#    thresholds       f1
# 2         0.0  0.11617
# 0         2.0  0.00000
# 1         1.0  0.00000

# %%
pred_best = model.predict_proba(X_test)[:,1]
pred_best[pred_best>0.116] =1
pred_best[pred_best<=0.116] =0

# %%
cm= confusion_matrix(y_test, pred_best)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred_best)
print('Precision: %f' % precision)

recall = recall_score(y_test,pred_best)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred_best)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7048  470]
#  [  93   37]]
# Precision: 0.072978
# Recall: 0.284615
# F1 score: 0.116170
# Sensitivity :  0.9869766139196191
# Specificity :  0.07297830374753451
# Negative predictive Value:  0.2846153846153846
# Positive Predictive Value:  0.9374833732375631
# Geometric Mean:  0.2683801019493417

# %%
space_lr = {'max_depth': hp.choice('max_depth', range(5, 70,1)),
                'learning_rate':hp.quniform('learning_rate',0.01,0.5,0.01),
            'n_estimators':hp.choice('n_estimators',range(20,200,5)),
            'gamma':hp.quniform('gamma',0,0.5,0.01),
            'min_child_weight':hp.quniform('min_child_weight',1,10,1),
            #'subsample':hp.quniform('subsample',0.1,1,0.01),
            #'colsample_bytree':hp.quniform('colsample_bytree',0.1,1,0.01),
            'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1)
            
        }


def xgb(params):
    params = {'max_depth': params['max_depth'],
                 'learning_rate': params['learning_rate'],
                  'gamma':params['gamma'],
                  
                'min_child_weight':params['min_child_weight'],
             # 'subsample':params['subsample'],
                  'n_estimators': params['n_estimators'],
            #  'colsample_bytree':params['colsample_bytree'],
              'sampling_strategy' : params['sampling_strategy']
                  
                 }

    xgb_bo = XGBClassifier(random_state=42,max_depth=params['max_depth'],learning_rate=params['learning_rate'], n_estimators = params['n_estimators'], gamma = params['gamma'], min_child_weight = params['min_child_weight'])
    cv= StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
    under = RandomUnderSampler(random_state=42, sampling_strategy=params['sampling_strategy'])
    pipe = Pipeline([('o', under),('m', xgb_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1 - best_score
xgb_best_param = fmin(fn=xgb,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print(xgb_best_param)
# Out:
#   0%|                                                       | 0/24 [00:00<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:34:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:00<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:00<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:01<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   0%|                                                       | 0/24 [00:01<?, ?trial/s, best loss=?]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                          | 1/24 [00:01<00:42,  1.86s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                          | 1/24 [00:02<00:42,  1.86s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                          | 1/24 [00:03<00:42,  1.86s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                          | 1/24 [00:03<00:42,  1.86s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|█▏                          | 1/24 [00:04<00:42,  1.86s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▎                         | 2/24 [00:04<00:48,  2.21s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▎                         | 2/24 [00:05<00:48,  2.21s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▎                         | 2/24 [00:05<00:48,  2.21s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▎                         | 2/24 [00:06<00:48,  2.21s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   8%|██▎                         | 2/24 [00:06<00:48,  2.21s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▌                        | 3/24 [00:06<00:43,  2.06s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▌                        | 3/24 [00:07<00:43,  2.06s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▌                        | 3/24 [00:07<00:43,  2.06s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▌                        | 3/24 [00:07<00:43,  2.06s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|███▌                        | 3/24 [00:07<00:43,  2.06s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:34:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  17%|████▋                       | 4/24 [00:08<00:38,  1.92s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:34:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  17%|████▋                       | 4/24 [00:08<00:38,  1.92s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:34:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|█████▊                      | 5/24 [00:09<00:30,  1.60s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:34:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|█████▊                      | 5/24 [00:09<00:30,  1.60s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:34:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|█████▊                      | 5/24 [00:09<00:30,  1.60s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████                     | 6/24 [00:09<00:23,  1.32s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████                     | 6/24 [00:10<00:23,  1.32s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████                     | 6/24 [00:10<00:23,  1.32s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████                     | 6/24 [00:10<00:23,  1.32s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  25%|███████                     | 6/24 [00:11<00:23,  1.32s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▏                   | 7/24 [00:11<00:25,  1.50s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:34:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▏                   | 7/24 [00:12<00:25,  1.50s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▏                   | 7/24 [00:12<00:25,  1.50s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▏                   | 7/24 [00:13<00:25,  1.50s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  29%|████████▏                   | 7/24 [00:13<00:25,  1.50s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▎                  | 8/24 [00:14<00:28,  1.77s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▎                  | 8/24 [00:14<00:28,  1.77s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▎                  | 8/24 [00:14<00:28,  1.77s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▎                  | 8/24 [00:14<00:28,  1.77s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  33%|█████████▎                  | 8/24 [00:15<00:28,  1.77s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▌                 | 9/24 [00:15<00:24,  1.62s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▌                 | 9/24 [00:15<00:24,  1.62s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:35:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▌                 | 9/24 [00:16<00:24,  1.62s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  38%|██████████▌                 | 9/24 [00:16<00:24,  1.62s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▎               | 10/24 [00:16<00:21,  1.54s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▎               | 10/24 [00:17<00:21,  1.54s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▎               | 10/24 [00:17<00:21,  1.54s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▎               | 10/24 [00:17<00:21,  1.54s/trial, best loss: 0.13313453568367462]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|███████████▎               | 10/24 [00:18<00:21,  1.54s/trial, best loss: 0.13313453568367462]
# ...
#  83%|██████████████████████▌    | 20/24 [00:37<00:07,  1.97s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  83%|██████████████████████▌    | 20/24 [00:38<00:07,  1.97s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  83%|██████████████████████▌    | 20/24 [00:39<00:07,  1.97s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|███████████████████████▋   | 21/24 [00:39<00:07,  2.60s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|███████████████████████▋   | 21/24 [00:40<00:07,  2.60s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|███████████████████████▋   | 21/24 [00:46<00:07,  2.60s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|███████████████████████▋   | 21/24 [00:48<00:07,  2.60s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|███████████████████████▋   | 21/24 [00:48<00:07,  2.60s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|████████████████████████▊  | 22/24 [00:50<00:09,  4.89s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|████████████████████████▊  | 22/24 [00:50<00:09,  4.89s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|████████████████████████▊  | 22/24 [00:51<00:09,  4.89s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|████████████████████████▊  | 22/24 [00:51<00:09,  4.89s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  92%|████████████████████████▊  | 22/24 [00:52<00:09,  4.89s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|█████████████████████████▉ | 23/24 [00:52<00:04,  4.13s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|█████████████████████████▉ | 23/24 [00:53<00:04,  4.13s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|█████████████████████████▉ | 23/24 [00:53<00:04,  4.13s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|█████████████████████████▉ | 23/24 [00:54<00:04,  4.13s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [08:35:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  96%|█████████████████████████▉ | 23/24 [00:55<00:04,  4.13s/trial, best loss: 0.12926439587124627]
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 100%|███████████████████████████| 24/24 [00:56<00:00,  2.36s/trial, best loss: 0.12926439587124627]
# {'gamma': 0.16, 'learning_rate': 0.14, 'max_depth': 28, 'min_child_weight': 2.0, 'n_estimators': 6, 'sampling_strategy': 0.1}

# %%
param_values = [x for x in xgb_best_param.values()]


xgb_best = XGBClassifier(random_state=42,
   gamma= param_values[0],
    learning_rate= param_values[1],
   max_depth= param_values[2],
   min_child_weight=param_values[3],
n_estimators = param_values[4]
)

under = RandomUnderSampler(random_state=42,sampling_strategy= param_values[5])
pipe = Pipeline([('o', under),('m', xgb_best)])
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)
# Out:
# [08:35:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print( 'Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7369  149]
#  [ 104   26]]
# Precision: 0.148571
# Recall: 0.200000
# F1 score: 0.170492
# Sensitivity :  0.9860832329720326
# Specificity :  0.14857142857142858
# Negative predictive Value:  0.2
# Positive Predictive Value:  0.9801808991753126
# Geometric Mean:  0.3827581411452769

# %%
r_probs=[0 for _ in range(len(y_test))]
xgb_probs=model.predict_proba(X_test)
xgb_probs=xgb_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
xgb_auc =roc_auc_score(y_test,xgb_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(xgb_auc))

xgb_precision, xgb_recall, _ = precision_recall_curve(y_test, xgb_probs,pos_label=1)
xgb_aucprc=auc(xgb_recall, xgb_precision)
print('AUC:PrecisionRecall Value =%.3f' % (xgb_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
xgb_fpr, xgb_tpr, thresholds = metrics.roc_curve(y_test, xgb_probs, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(xgb_fpr,xgb_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%xgb_auc)
plt.title('ROC PLOT - XGB ')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#plt.savefig('XBB_plot1.png', dpi=300, bbox_inches='tight')
plt.show()

plt.plot(xgb_recall, xgb_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%xgb_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - XGB')
plt.legend()
    #save plot
#plt.savefig('XGB_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.873926
# AUC:PrecisionRecall Value =0.110
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
from sklearn.calibration import calibration_curve
xgb_probs=model.predict_proba(X_test)
xgb_probs=xgb_probs[:,1]

x,y= calibration_curve(y_test,xgb_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='xgb')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('XGB_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
xgb_probs = xgb_best.predict_proba(X_test)
xgb_probs=xgb_probs[:,1]
fpr, tpr,thresholds = roc_curve(y_test, xgb_probs)
thresholds
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# array([1.7220132 , 0.7220132 , 0.71449083, 0.71139324, 0.70753354,
#        0.69395757, 0.6514072 , 0.6507492 , 0.64040804, 0.6381062 ,
#        0.6292357 , 0.6256067 , 0.6248181 , 0.6243027 , 0.6217196 ,
#        0.61065733, 0.6066986 , 0.60222167, 0.60005015, 0.5996396 ,
#        0.5965577 , 0.5945037 , 0.5932659 , 0.59263337, 0.5921744 ,
#        0.5897247 , 0.5888089 , 0.58781976, 0.5863068 , 0.58207285,
#        0.5805781 , 0.5800537 , 0.57984656, 0.5678599 , 0.566602  ,
#        0.22291748, 0.22269292, 0.22267222, 0.22249809, 0.22234565,
#        0.22216083, 0.2221252 , 0.22188064, 0.22181626, 0.22163516,
#        0.22156681, 0.2215666 , 0.2214676 , 0.2213675 , 0.22135375,
#        0.22128561, 0.22122538, 0.22116789, 0.22113806, 0.22082327,
#        0.22077505, 0.22071174, 0.22066578, 0.22042514, 0.22041687,
#        0.22033721, 0.22019322, 0.22017926, 0.22014774, 0.21995422,
#        0.21995404, 0.21990222, 0.21981928, 0.21960208, 0.21956962,
#        0.21946391, 0.21934864, 0.2193204 , 0.21930127, 0.21929671,
#        0.21929178, 0.21925282, 0.21922533, 0.2191796 , 0.2191501 ,
#        0.21913223, 0.2190988 , 0.21908167, 0.21892846, 0.21892388,
#        0.2188818 , 0.2188027 , 0.21879415, 0.21878351, 0.2185269 ,
#        0.21848631, 0.2184849 , 0.2184329 , 0.2181771 , 0.21817555,
#        0.21811303, 0.21810482, 0.2180576 , 0.21802786, 0.21802382,
#        0.21802025, 0.21796486, 0.21792804, 0.21791   , 0.21779487,
#        0.2177825 , 0.21776184, 0.21772541, 0.21766543, 0.217635  ,
#        0.21761307, 0.21746562, 0.21732001, 0.21729618, 0.21725877,
#        0.21722545, 0.21720365, 0.2171534 , 0.21712703, 0.21709365,
#        0.2169496 , 0.21687624, 0.21687225, 0.21683587, 0.21670733,
#        0.2162077 , 0.2161359 , 0.21609862, 0.21598922, 0.21598521,
#        0.21582077], dtype=float32)

# %%
from sklearn.metrics import f1_score
f1_ls =[]
for thres in thresholds:
    y_pred = np.where(xgb_probs> thres, 1,0)
    f1_ls.append(f1_score(y_test,y_pred))
f1_ls = pd.concat([pd.Series(thresholds),pd.Series(f1_ls)], axis=1)
f1_ls.columns= ['thresholds', 'f1']
f1_ls.sort_values(by='f1', ascending = False, inplace=True)
f1_ls
# Out:
#      thresholds        f1
# 138    0.393098  0.213689
# 139    0.392332  0.213333
# 136    0.397304  0.212838
# 137    0.396444  0.212479
# 132    0.399306  0.211604
# ..          ...       ...
# 7      0.650749  0.013423
# 1      0.722013  0.000000
# 3      0.711393  0.000000
# 2      0.714491  0.000000
# 0      1.722013  0.000000
#
# [726 rows x 2 columns]

# %%
pred_best = model.predict_proba(X_test)[:,1]
pred_best[pred_best>0.39] =1
pred_best[pred_best<=0.39] =0
# Out:
# C:\Program Files\Python39\python-3.9.0rc1.amd64\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
cm= confusion_matrix(y_test, pred_best)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred_best)
print('Precision: %f' % precision)

recall = recall_score(y_test,pred_best)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred_best)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7103  415]
#  [  66   64]]
# Precision: 0.133612
# Recall: 0.492308
# F1 score: 0.210181
# Sensitivity :  0.9907936950760218
# Specificity :  0.1336116910229645
# Negative predictive Value:  0.49230769230769234
# Positive Predictive Value:  0.9447991487097632
# Geometric Mean:  0.36384285214086415

# %%
#Random Forest Classifier hyper parameter tuning


start = time.time()
space_lr = {'max_depth': hp.randint('max_depth', 6,15),
                'max_features': hp.choice('max_features',['sqrt','log2']),
                'n_estimators': hp.randint('n_estimators', 100,1000),
                'criterion': hp.choice('criterion', ['entropy','gini']),
             'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1),
            'class_weight':hp.choice('class_weight',['balanced_subsample','balanced'])
                    }

def rf(params):
    params = {'max_depth': params['max_depth'],
                  'max_features': params['max_features'],
                  'n_estimators': params['n_estimators'],
                  'criterion': params['criterion'],
              'sampling_strategy': params['sampling_strategy'],
              'class_weight':params['class_weight']
             }
    rf_bo = sklearn.ensemble.RandomForestClassifier(random_state=42,class_weight=params['class_weight'], max_depth=params['max_depth'],max_features= params['max_features'],n_estimators=params['n_estimators'],criterion= params['criterion'])
    cv= StratifiedKFold(n_splits=5,random_state=42, shuffle=True)
    under = RandomOverSampler(random_state=42,sampling_strategy=params['sampling_strategy'])
    pipe = Pipeline([('o', under),('m', rf_bo)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1-best_score

rf_best_param = fmin(fn=rf,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest,
                        )
print('It takes %s minutes' % ((time.time() - start)/60))
print('Random Forest Best Parameters',rf_best_param)
# Out:
# 100%|███████████████████████████| 24/24 [36:16<00:00, 90.69s/trial, best loss: 0.12877848899255384]
# It takes 36.277461528778076 minutes
# Random Forest Best Parameters {'class_weight': 0, 'criterion': 0, 'max_depth': 6, 'max_features': 1, 'n_estimators': 595, 'sampling_strategy': 0.2}

# %%
param_values = [x for x in rf_best_param.values()]

if param_values[1] == 1:
    criterion = 'gini'
else:
    criterion= 'entropy'

if param_values[3] == 1:
    max_features = 'log2'
else:
    max_features= 'sqrt'
    
if param_values[0] == 1:
    class_weight = 'balanced'
else:
    class_weight= 'balanced_subsample'

rf_best = sklearn.ensemble.RandomForestClassifier(random_state=42,
criterion= criterion,
max_depth= param_values[2],
max_features= max_features,
n_estimators=param_values[4],
class_weight = class_weight)
under=RandomUnderSampler(random_state=42,sampling_strategy=param_values[5])
pipe = Pipeline([('o', under),('m', rf_best)])
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

cm = confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6517 1001]
#  [  27  103]]
# Precision: 0.093297
# Recall: 0.792308
# F1 score: 0.166937
# Sensitivity :  0.9958740831295844
# Specificity :  0.09329710144927536
# Negative predictive Value:  0.7923076923076923
# Positive Predictive Value:  0.866852886405959
# Geometric Mean:  0.30481496906229016

# %%
r_probs=[0 for _ in range(len(y_test))]
rf_probs=model.predict_proba(X_test)
rf_probs=rf_probs[:,1]
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
rf_auc =roc_auc_score(y_test,rf_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(rf_auc))

rf_precision, rf_recall, _ = precision_recall_curve(y_test, rf_probs,pos_label=1)
rf_aucprc=auc(rf_recall, rf_precision)
print('AUC:PrecisionRecall Value =%.3f' % (rf_aucprc))
    
r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
rf_fpr, rf_tpr, thresholds = metrics.roc_curve(y_test, rf_probs, pos_label=1)

#ROC PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(rf_fpr,rf_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%rf_auc)
plt.title('ROC PLOT - RF')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
plt.savefig('RF_plot1.png', dpi=300, bbox_inches='tight')
plt.show()

plt.plot(rf_recall, rf_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%rf_aucprc)
# axis labels
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.title('PRC PLOT - RF')
# show the legend
plt.legend()
#save
plt.savefig('RF_plot2.png', dpi=300, bbox_inches='tight')
#show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.908268
# AUC:PrecisionRecall Value =0.160

# %%
from sklearn.calibration import calibration_curve
rf_probs=model.predict_proba(X_test)
rf_probs=rf_probs[:,1]

x,y= calibration_curve(y_test,rf_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='rf')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('RF_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
rf_probs=rf_best.predict_proba(X_test)
rf_probs=rf_probs[:,1]
fpr, tpr,thresholds = roc_curve(y_test, rf_probs)
thresholds
# Out:
# array([1.86353857, 0.86353857, 0.84840325, 0.84723104, 0.84302351,
#        0.83653503, 0.82680448, 0.82213126, 0.80739131, 0.80665776,
#        0.79823409, 0.79700144, 0.79611887, 0.79562441, 0.79361702,
#        0.79358108, 0.78893911, 0.78785868, 0.78603798, 0.78572549,
#        0.7839818 , 0.78390543, 0.78300832, 0.78065584, 0.77610552,
#        0.77607276, 0.7752506 , 0.77494779, 0.77339882, 0.77196826,
#        0.76941358, 0.76897931, 0.76811444, 0.76728475, 0.76688074,
#        0.76610772, 0.76300269, 0.76283951, 0.76278465, 0.76268936,
#        0.75915701, 0.75890884, 0.75717136, 0.75702648, 0.75487673,
#        0.75476695, 0.75444827, 0.7543028 , 0.75360124, 0.75345208,
#        0.75223897, 0.7520084 , 0.74827774, 0.74712829, 0.74340016,
#        0.74266998, 0.74134133, 0.74075086, 0.7393817 , 0.73921366,
#        0.73869746, 0.73867369, 0.73766677, 0.7372945 , 0.731871  ,
#        0.73158785, 0.73071231, 0.73030953, 0.72665857, 0.72633045,
#        0.72446542, 0.72341719, 0.72337226, 0.72257044, 0.72097675,
#        0.72084972, 0.71511215, 0.71474375, 0.71085128, 0.71039646,
#        0.7062825 , 0.70583904, 0.69966739, 0.69959189, 0.69789717,
#        0.69649823, 0.69605411, 0.6954959 , 0.68992662, 0.68986245,
#        0.68796315, 0.68792201, 0.68524442, 0.68512865, 0.68426148,
#        0.68418786, 0.68306648, 0.68245402, 0.68064227, 0.68030198,
#        0.67911216, 0.67906659, 0.67474889, 0.67469428, 0.6736597 ,
#        0.67324801, 0.67042578, 0.66998392, 0.66354941, 0.66335541,
#        0.65895422, 0.65822875, 0.65553781, 0.65546014, 0.65260933,
#        0.65252388, 0.65091123, 0.65083004, 0.65073762, 0.65032953,
#        0.65009167, 0.65001122, 0.64178418, 0.64158643, 0.64082292,
#        0.64073982, 0.63839734, 0.63827804, 0.62204239, 0.6218618 ,
#        0.61865948, 0.61827874, 0.61304645, 0.61297349, 0.61198279,
#        0.61131624, 0.60929747, 0.60911255, 0.60783876, 0.60775095,
#        0.59137037, 0.59128791, 0.58597894, 0.58577728, 0.57988354,
#        0.57977506, 0.5785042 , 0.57816929, 0.57455855, 0.57432886,
#        0.56738025, 0.56728685, 0.55425396, 0.55397316, 0.55105121,
#        0.55083308, 0.5424747 , 0.54247157, 0.53811892, 0.53803336,
#        0.53645272, 0.53636623, 0.53470164, 0.53460284, 0.52951064,
#        0.52948912, 0.52925362, 0.52924725, 0.52836824, 0.52823809,
#        0.52141772, 0.52139664, 0.51863002, 0.5183057 , 0.51652672,
#        0.51631152, 0.51183634, 0.51164739, 0.4803851 , 0.48028835,
#        0.47963134, 0.47946635, 0.47767229, 0.4775675 , 0.47469486,
#        0.47461913, 0.47386901, 0.47381166, 0.45653792, 0.45637699,
#        0.45365853, 0.45355205, 0.44897927, 0.44889307, 0.42978844,
#        0.42974822, 0.42257943, 0.42257575, 0.41932879, 0.41905537,
#        0.41752431, 0.41726142, 0.41341105, 0.41335538, 0.40939243,
#        0.40897622, 0.39688453, 0.3968306 , 0.3909879 , 0.39081666,
#        0.37715757, 0.37682582, 0.37393452, 0.37390556, 0.35147179,
#        0.35117368, 0.28732139, 0.28711794, 0.24826945, 0.24796125,
#        0.24776794, 0.24759083, 0.22686343, 0.22670934, 0.21955841,
#        0.21955294, 0.20408751, 0.20400914, 0.14330898, 0.14325693,
#        0.11625101, 0.11620361, 0.04083214])

# %%
from sklearn.metrics import f1_score
f1_ls =[]
for thres in thresholds:
    y_pred = np.where(rf_probs> thres, 1,0)
    f1_ls.append(f1_score(y_test,y_pred))
f1_ls = pd.concat([pd.Series(thresholds),pd.Series(f1_ls)], axis=1)
f1_ls.columns= ['thresholds', 'f1']
f1_ls.sort_values(by='f1', ascending = False, inplace=True)
f1_ls
# Out:
#     thresholds        f1
# 74    0.720977  0.268657
# 75    0.720850  0.267857
# 62    0.737667  0.265306
# 72    0.723372  0.265060
# 63    0.737295  0.264407
# ..         ...       ...
# 4     0.843024  0.014599
# 1     0.863539  0.000000
# 3     0.847231  0.000000
# 2     0.848403  0.000000
# 0     1.863539  0.000000
#
# [233 rows x 2 columns]

# %%
pred_best = model.predict_proba(X_test)[:,1]
pred_best[pred_best>0.72] =1
pred_best[pred_best<=0.72] =0

# %%
cm= confusion_matrix(y_test, pred_best)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred_best)
print('Precision: %f' % precision)

recall = recall_score(y_test,pred_best)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred_best)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7356  162]
#  [  84   46]]
# Precision: 0.221154
# Recall: 0.353846
# F1 score: 0.272189
# Sensitivity :  0.9887096774193549
# Specificity :  0.22115384615384615
# Negative predictive Value:  0.35384615384615387
# Positive Predictive Value:  0.9784517158818835
# Geometric Mean:  0.4676076858765464

# %%
#Logistic Regression Hyper Parameter tuning

start = time.time()
space_lr = {'penalty': 'elasticnet',
               'C' : hp.quniform('C',1,1000,10),
                'solver': 'saga',
              # 'class_weight' : 'balanced',
               'max_iter': hp.randint('max_iter', 1000,50000) ,
               'l1_ratio':hp.quniform('l1_ratio',0.1,0.9,0.1),
             'sampling_strategy':hp.quniform('sampling_strategy',0.1,0.9,0.1)
               }
def lr(params):
    params = {'penalty': params['penalty'],
                 'C': params['C'],
                  #'class_weight': params['class_weight'],                       
                  'solver': params['solver'],
                 'max_iter':params['max_iter'],
              'l1_ratio':params['l1_ratio'],
              'sampling_strategy':params['sampling_strategy']
             }
    lr_bo2 =sklearn.linear_model.LogisticRegression(random_state=42,class_weight='balanced',penalty=params['penalty'], C= params['C'], solver = params['solver'],max_iter = params['max_iter'], l1_ratio= params['l1_ratio'])
    cv= StratifiedKFold(n_splits=5, random_state=42, shuffle= True)
    over = RandomUnderSampler(sampling_strategy=params['sampling_strategy'], random_state=42)
    pipe = Pipeline([('o', over),('m', lr_bo2)])
    best_score = cross_val_score(pipe, X_train, y_train, scoring='roc_auc', cv=cv).mean()
    return 1 - best_score

lr_best_param = fmin(fn=lr,
                    space=space_lr,
                    max_evals=24,
                    rstate=np.random.RandomState(42),
                    algo=tpe.suggest)
print('It takes %s minutes' % ((time.time() - start)/60))
print('Best Paramters for Logistic Regression Elastic Net model',lr_best_param)
# Out:
# 100%|███████████████████████████| 24/24 [00:11<00:00,  2.17trial/s, best loss: 0.12582206703955767]
# It takes 0.1846439242362976 minutes
# Best Paramters for Logistic Regression Elastic Net model {'C': 510.0, 'l1_ratio': 0.1, 'max_iter': 16463, 'sampling_strategy': 0.2}

# %%
param_values = [x for x in lr_best_param.values()]

C= param_values[0]
l1_ratio=param_values[1]
max_iter = param_values[2]

        
lr_best= sklearn.linear_model.LogisticRegression(random_state=42,class_weight='balanced',solver='saga',l1_ratio=l1_ratio,penalty='elasticnet',C=C,max_iter=max_iter)
under=RandomUnderSampler(sampling_strategy=param_values[3], random_state=42)
pipe = Pipeline([('o', under),('m', lr_best)])
model= pipe.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
#Printing the performance metrics

cm= confusion_matrix(y_test, pred)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred)
print(' Precision: %f' % precision)

recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred)
print(' F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print(' Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print(' Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[6279 1239]
#  [  20  110]]
#  Precision: 0.081542
# Recall: 0.846154
#  F1 score: 0.148749
# Sensitivity :  0.9968248928401333
#  Specificity :  0.08154188287620459
# Negative predictive Value:  0.8461538461538461
#  Positive Predictive Value:  0.835195530726257
# Geometric Mean:  0.2851016988024718

# %%
r_probs=[0 for _ in range(len(y_test))]
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]
    
from sklearn.metrics import roc_curve, roc_auc_score
r_auc=roc_auc_score(y_test,r_probs)
lr_auc =roc_auc_score(y_test,lr_probs)
print('Random chance= %3f'%(r_auc))
print('AUCROC Value = %4f'%(lr_auc))

     
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs,pos_label=1)
lr_aucprc=auc(lr_recall, lr_precision)
print('AUC:PrecisionRecall=%.3f' % (lr_aucprc))

r_fpr, r_tpr, thresholds = metrics.roc_curve(y_test, r_probs, pos_label=1)
lr_fpr, lr_tpr, thresholds = metrics.roc_curve(y_test, lr_probs, pos_label=1)

#ROC CURVE PLOT
import matplotlib.pyplot as plt
plt.plot(r_fpr,r_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%r_auc)
plt.plot(lr_fpr,lr_tpr,linestyle='--',label='Random prediction(AUCROC=%0.3f)'%lr_auc)
plt.title('ROC PLOT - LR ELASTIC MODEL')
plt.xlabel('FALSE POSITIVE RATE')
plt.ylabel('TRUE POSITIVE RATE')
plt.legend()
#save
plt.savefig('lr_elastic_plot1.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()

#PRECISION RECALL PLOT
    
plt.plot(lr_recall, lr_precision, linestyle='--', label='Random prediction(AUCPRC=%0.3f)'%lr_aucprc)
plt.xlabel('RECALL')
plt.ylabel('PRECISION')
plt.legend()
plt.title('PRC PLOT - LR ELASTIC MODEL')
#save
plt.savefig('lr_elastic_plot2.png', dpi=300, bbox_inches='tight')
    # show the plot
plt.show()
# Out:
# Random chance= 0.500000
# AUCROC Value = 0.908957
# AUC:PrecisionRecall=0.170

# %%
#saving file
lr_probs=model.predict_proba(X_test)
lr_pos=lr_probs[:,1]
lr_neg=lr_probs[:,0]
pd.DataFrame({'Actual': y_test,'Pred_LR': pred, 'PredProb_1_LR_ELASTIC': lr_pos,'PredProb_0_LR_ELASTIC':lr_neg}).to_csv('lr_elastic.csv', index=False)

# %%
from sklearn.calibration import calibration_curve
lr_probs=model.predict_proba(X_test)
lr_probs=lr_probs[:,1]

x,y= calibration_curve(y_test,lr_probs, n_bins=50)
plt.plot([0,1],[0,1], linestyle='--', label='Ideally Calibrated')
plt.plot(y,x, marker='o', linewidth=1, label='lr')
leg= plt.legend(loc='upper left')
plt.xlabel('average predicted probabilty in each bin')
plt.ylabel('Ratio of Positives')
plt.savefig('lr_elastic_calibration1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Printing the coefficient Values

print('Coefficient Values:',pipe['m'].coef_)
print('Intercept Model :',pipe['m'].intercept_)
# Out:
# Coefficient Values: [[ 0.48414337 -0.07117536  0.80104306 -0.12087956  0.43005825  0.48666538
#    0.11502875 -0.2359109  -0.17952835  0.00372825  0.49012317 -0.01493961
#    0.05722801 -0.21252517  0.12084364 -0.6146468  -0.08031335  0.30579487
#   -0.29910962 -0.05874029 -0.16274853  0.29149852  0.27946289  0.06325019
#    0.26046773  0.06622684 -0.13186147  0.06008725  0.20651598  0.23196575]]
# Intercept Model : [-1.40299568]

# %%
lr_probs = lr_best.predict_proba(X_test)
lr_probs=lr_probs[:,1]
fpr, tpr,thresholds = roc_curve(y_test, lr_probs)
thresholds
# Out:
# array([1.99999976e+00, 9.99999758e-01, 9.99653706e-01, 9.99646661e-01,
#        9.96858605e-01, 9.95158613e-01, 9.91001558e-01, 9.89796161e-01,
#        9.89793601e-01, 9.88325012e-01, 9.81718583e-01, 9.80895001e-01,
#        9.80087454e-01, 9.77720460e-01, 9.77149131e-01, 9.77085454e-01,
#        9.75233599e-01, 9.74771839e-01, 9.72882471e-01, 9.70912985e-01,
#        9.70553163e-01, 9.69578716e-01, 9.69298612e-01, 9.68911928e-01,
#        9.63555865e-01, 9.63308184e-01, 9.63035649e-01, 9.61329437e-01,
#        9.60109878e-01, 9.59912669e-01, 9.58169001e-01, 9.56864818e-01,
#        9.55720462e-01, 9.55255727e-01, 9.48986091e-01, 9.48666043e-01,
#        9.44456372e-01, 9.44428801e-01, 9.33813164e-01, 9.33236259e-01,
#        9.32364453e-01, 9.30794195e-01, 9.30443925e-01, 9.30111568e-01,
#        9.26888336e-01, 9.26869587e-01, 9.21386954e-01, 9.20574306e-01,
#        9.19220171e-01, 9.19187670e-01, 9.15839913e-01, 9.14991771e-01,
#        9.14284359e-01, 9.13549309e-01, 9.09485283e-01, 9.09484845e-01,
#        9.04348251e-01, 9.04205880e-01, 9.02907715e-01, 9.02578950e-01,
#        9.00446113e-01, 8.99463790e-01, 8.75906727e-01, 8.75805072e-01,
#        8.71727582e-01, 8.71360407e-01, 8.68306835e-01, 8.68247001e-01,
#        8.66872386e-01, 8.65857207e-01, 8.59355068e-01, 8.59320626e-01,
#        8.53678153e-01, 8.53359902e-01, 8.51209862e-01, 8.51173631e-01,
#        8.45071742e-01, 8.44743320e-01, 8.32445213e-01, 8.32400588e-01,
#        8.26423004e-01, 8.25688476e-01, 8.25254637e-01, 8.25012718e-01,
#        8.24669666e-01, 8.23548278e-01, 8.19724326e-01, 8.19368114e-01,
#        8.16235853e-01, 8.16145095e-01, 8.13442559e-01, 8.13072012e-01,
#        8.07495078e-01, 8.07362330e-01, 8.06507114e-01, 8.06203453e-01,
#        8.02693164e-01, 8.01680749e-01, 8.00966257e-01, 7.99824252e-01,
#        7.98884478e-01, 7.98204642e-01, 7.94663181e-01, 7.94180743e-01,
#        7.93872132e-01, 7.93803915e-01, 7.91551978e-01, 7.91533545e-01,
#        7.87014733e-01, 7.85431616e-01, 7.76879752e-01, 7.76862669e-01,
#        7.73766749e-01, 7.73726759e-01, 7.66914276e-01, 7.66899533e-01,
#        7.57069102e-01, 7.56969043e-01, 7.52035720e-01, 7.51984033e-01,
#        7.50704404e-01, 7.49785145e-01, 7.48400681e-01, 7.47792610e-01,
#        7.36574770e-01, 7.36446563e-01, 7.26085540e-01, 7.25331903e-01,
#        6.98437255e-01, 6.98210706e-01, 6.87722226e-01, 6.87502824e-01,
#        6.87397034e-01, 6.87288279e-01, 6.83495938e-01, 6.83014529e-01,
#        6.82353764e-01, 6.82020095e-01, 6.80661145e-01, 6.80200559e-01,
#        6.78901588e-01, 6.78816400e-01, 6.78380756e-01, 6.76707267e-01,
#        6.64693568e-01, 6.64343270e-01, 6.50421351e-01, 6.50266042e-01,
#        6.46004480e-01, 6.45863068e-01, 6.38074380e-01, 6.37636646e-01,
#        6.36917088e-01, 6.36447683e-01, 6.31505337e-01, 6.31197970e-01,
#        6.27988565e-01, 6.27500227e-01, 6.01306616e-01, 6.00857852e-01,
#        5.96819066e-01, 5.96354187e-01, 5.66835550e-01, 5.66677975e-01,
#        5.64397349e-01, 5.64303458e-01, 5.64302463e-01, 5.64042438e-01,
#        5.56421154e-01, 5.55815060e-01, 5.51776550e-01, 5.51681769e-01,
#        5.12989406e-01, 5.12794607e-01, 5.10595850e-01, 5.10100893e-01,
#        5.03598617e-01, 5.03057617e-01, 5.00330695e-01, 4.99945910e-01,
#        4.63369591e-01, 4.62488633e-01, 4.45731076e-01, 4.45563252e-01,
#        4.22154663e-01, 4.21824267e-01, 4.20425298e-01, 4.20337556e-01,
#        3.94469948e-01, 3.93670847e-01, 3.90290636e-01, 3.90157121e-01,
#        3.89484358e-01, 3.89380791e-01, 3.23226807e-01, 3.23159781e-01,
#        3.18433597e-01, 3.18237241e-01, 3.04339757e-01, 3.04325107e-01,
#        2.98178733e-01, 2.98107198e-01, 2.79660173e-01, 2.79631877e-01,
#        2.26392188e-01, 2.26380304e-01, 1.93269331e-01, 1.93262204e-01,
#        1.86437818e-01, 1.86414835e-01, 1.52140746e-01, 1.52062311e-01,
#        1.37353291e-01, 1.37215472e-01, 1.26203947e-01, 1.26158518e-01,
#        7.59828338e-02, 7.59611966e-02, 1.78396176e-03])

# %%
from sklearn.metrics import f1_score
f1_ls =[]
for thres in thresholds:
    y_pred = np.where(lr_probs> thres, 1,0)
    f1_ls.append(f1_score(y_test,y_pred))
f1_ls = pd.concat([pd.Series(thresholds),pd.Series(f1_ls)], axis=1)
f1_ls.columns= ['thresholds', 'f1']
f1_ls.sort_values(by='f1', ascending = False, inplace=True)
f1_ls
# Out:
#     thresholds        f1
# 52    0.914284  0.263889
# 53    0.913549  0.262976
# 60    0.900446  0.262500
# 61    0.899464  0.261682
# 54    0.909485  0.260000
# ..         ...       ...
# 5     0.995159  0.028777
# 2     0.999654  0.015038
# 3     0.999647  0.014925
# 1     1.000000  0.000000
# 0     2.000000  0.000000
#
# [219 rows x 2 columns]

# %%
pred_best = model.predict_proba(X_test)[:,1]
pred_best[pred_best>0.914] =1
pred_best[pred_best<=0.914] =0

# %%
cm= confusion_matrix(y_test, pred_best)
print('Confusion Matrix:\n',cm)

precision = precision_score(y_test, pred_best)
print('Precision: %f' % precision)

recall = recall_score(y_test,pred_best)
print('Recall: %f' % recall)

f1 = f1_score(y_test, pred_best)
print('F1 score: %f' % f1)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity )

specificity = cm[1,1]/(cm[0,1]+cm[1,1])
print('Specificity : ', specificity)

NPV = cm[1,1]/(cm[1,1]+cm[1,0])
print('Negative predictive Value: ', NPV)

PPV = cm[0,0]/(cm[0,0]+cm[0,1])
print('Positive Predictive Value: ', PPV)

import math
gm=math.sqrt(specificity*sensitivity)
print('Geometric Mean: ', gm)
# Out:
# Confusion Matrix:
#  [[7397  121]
#  [  92   38]]
# Precision: 0.238994
# Recall: 0.292308
# F1 score: 0.262976
# Sensitivity :  0.9877153157965015
# Specificity :  0.2389937106918239
# Negative predictive Value:  0.2923076923076923
# Positive Predictive Value:  0.9839052939611599
# Geometric Mean:  0.4858577450544064
